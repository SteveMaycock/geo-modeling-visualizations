# %%
import pandas as pd
import pyam
import aneris
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load data

# %%
aim_path = '../../../data/TOD/model_results/raw/Consolidated_AIM_GEO7_240621.xlsx'
aim_trade_path = '../../../data/TOD/model_results/raw/240513_GEO7_AIM.xlsx'
image_path = '../../../data/TOD/model_results/raw/Consolidated_IMAGE_GEO7_R3_results_12022025_0956.xlsx'

# %%
variables_to_load = [
    'Agricultural Demand',
    'Agricultural Demand|Energy',
    'Agricultural Demand|Energy|Crops',
    'Agricultural Demand|Energy|Residues',
    'Agricultural Demand|Non-Energy|Crops',
    'Agricultural Demand|Non-Energy|Crops|Feed',
    'Agricultural Demand|Non-Energy|Crops|Food',
    'Agricultural Demand|Non-Energy|Crops|Other',
    'Agricultural Demand|Non-Energy|Livestock',
    'Agricultural Production',
    'Agricultural Production|Energy|Crops',
    'Agricultural Production|Non-Energy|Crops', 
    'Agricultural Production|Non-Energy|Livestock',
    'Agricultural Production|Crops|Non-Energy|Maize',
    'Agricultural Production|Crops|Non-Energy|Rice',
    'Agricultural Production|Crops|Non-Energy|Soybeans',
    'Agricultural Production|Crops|Non-Energy|Wheat',
    'Emissions|CH4',
    'Emissions|CH4|AFOLU',
    'Emissions|CH4|Energy',
    'Emissions|CO2',
    'Emissions|CO2|AFOLU',
    'Emissions|CO2|Energy',
    'Emissions|N2O',
    'Emissions|N2O|AFOLU',
    'Emissions|N2O|Energy',
    'Emissions|Kyoto Gases',
    'Emissions|BC', 
    'Emissions|CO', 
    'Emissions|NOx', 
    'Emissions|NH3', 
    'Emissions|OC', 
    'Emissions|Sulfur', 
    'Emissions|VOC',
    'Emissions|F-Gases',
    'Land Cover|Built-up Area', 
    'Land Cover|Cropland',
    'Land Cover|Forest',
    'Land Cover|Pasture',
    'Land Cover|Other Natural Land',
    'Water Withdrawal',
    'Water Consumption',
    'Water Consumption|Electricity',
    'Water Consumption|Industrial Water',
    'Water Consumption|Irrigation',
    'Water Consumption|Municipal Water',
    'Water Withdrawal|Electricity',
    'Water Withdrawal|Industrial Water',
    'Water Withdrawal|Irrigation',
    'Water Withdrawal|Municipal Water',
    'Primary Energy',
    'Primary Energy|Biomass',
    'Primary Energy|Biomass|w/o CCS',
    'Primary Energy|Coal',
    'Primary Energy|Coal|w/o CCS',
    'Primary Energy|Gas',
    'Primary Energy|Gas|w/o CCS',
    'Primary Energy|Oil',
    'Primary Energy|Oil|w/o CCS',
    'Primary Energy|Hydro',
    'Primary Energy|Non-Biomass Renewables',
    'Primary Energy|Nuclear',
    'Primary Energy|Solar',
    'Primary Energy|Wind',
    'Primary Energy|Biomass|Traditional',
    'Food Demand*',
    'Final Energy',
    'Final Energy|Electricity',
    'Final Energy|Industry',
    'Final Energy|Other Sector',
    'Final Energy|Residential and Commercial',
    'Final Energy|Transportation',
    'Final Energy|Hydrogen',
    'Final Energy|Heat',
    'Final Energy|Gases',
    'Final Energy|Liquids',
    'Final Energy|Solids',
    'Secondary Energy|Electricity',
    'Secondary Energy|Electricity|Biomass',
    'Secondary Energy|Electricity|Coal',
    'Secondary Energy|Electricity|Gas',
    'Secondary Energy|Electricity|Non-Biomass Renewables',
    'Secondary Energy|Electricity|Nuclear',
    'Secondary Energy|Electricity|Oil',
    'Secondary Energy|Electricity|Hydro',
    'Secondary Energy|Electricity|Solar',
    'Secondary Energy|Electricity|Wind',
    "Temperature|Global Mean",
    'Yield|*',
    'Emissions|CO2|Energy|Demand|Residential',
    'Emissions|CO2|Energy|Demand|Industry',
    'Emissions|CO2|Industrial Processes',
    'Emissions|CO2|Energy|Demand|Transportation',
    'Emissions|CO2|Energy and Industrial Processes',
    'Carbon Sequestration|Direct Air Capture',
]

# Load Data
df_aim = pyam.IamDataFrame(aim_path)
# Add population here as an exception, needed for aggregation, remove later because we only want to share the image population
df_aim = df_aim.filter(
                     variable=variables_to_load + ['Population'],
                     scenario=['REF-v2'],
                    )

df_image_all = pyam.IamDataFrame(image_path)
df_image = df_image_all.filter(
                     variable=variables_to_load,
                     scenario=['TECH-TP-v2', 'LIFE-TP-v2'],
                    )

# IMAGE has uploaded results for 'Agricultural Demand|Non-Energy|Livestock', 
# assumed to be the same as "Agricultural Demand|Non-Energy|Livestock|Food"
df_image.aggregate("Agricultural Demand|Non-Energy|Livestock|Food", 
                       components=['Agricultural Demand|Non-Energy|Livestock'], 
                        append=True)

# Add population here as an exception, needed for aggregation, remove later
df_image_hist = df_image_all.filter(
                     variable=variables_to_load + ['Population'],
                     scenario='REF-v2',
                    )

# On world level water consumption gets reported as 0 by IMAGE, easier to aggregate it here
df_image = df_image.filter(variable='Water Consumption', region='World', keep=False)
df_image.aggregate_region(variable='Water Consumption', append=True)

df_image_hist = df_image_hist.filter(variable='Water Consumption', region='World', keep=False)
df_image_hist.aggregate_region(variable='Water Consumption', append=True)

# On world level water withdrawal misses some sectors, easier to aggregate it here
df_image = df_image.filter(variable='Water Withdrawal', region='World', keep=False)
df_image.aggregate_region(variable='Water Withdrawal', append=True)

df_image_hist = df_image_hist.filter(variable='Water Withdrawal', region='World', keep=False)
df_image_hist.aggregate_region(variable='Water Withdrawal', append=True)

# Read in GDP and Population from IMAGE for REF as well, vassilis mentioned consistency
# Read in w/ CCS primary energy categories as well, not uploaded for REF by AIM
df_gdp = df_image_all.filter(
                     variable=[
                        'GDP|PPP', 
                        'Population', 
                        'GDP|MER',
                        'Primary Energy|Biomass|w/ CCS',
                        'Primary Energy|Coal|w/ CCS',
                        'Primary Energy|Gas|w/ CCS',
                        'Primary Energy|Oil|w/ CCS',
                        ],
                     scenario=['REF-v2','TECH-TP-v2', 'LIFE-TP-v2'],
                    )

df_gdp.divide('GDP|PPP', 'Population', 'GDP|PPP|Per Capita', ignore_units='thousand USD_2010/yr', append=True)
# Out:
# [INFO] 10:26:41 - pyam.core: Reading file ..\..\..\data\TOD\model_results\raw\Consolidated_AIM_GEO7_240621.xlsx
# INFO:pyam.core:Reading file ..\..\..\data\TOD\model_results\raw\Consolidated_AIM_GEO7_240621.xlsx
# [INFO] 10:26:50 - pyam.core: Reading file ..\..\..\data\TOD\model_results\raw\Consolidated_IMAGE_GEO7_R3_results_12022025_0956.xlsx
# INFO:pyam.core:Reading file ..\..\..\data\TOD\model_results\raw\Consolidated_IMAGE_GEO7_R3_results_12022025_0956.xlsx

# %%
# Trade variables were not uploaded with the consolidated values for AIM
df_not_on_db_aim = pyam.IamDataFrame(aim_trade_path)
df_not_on_db_aim = df_not_on_db_aim.filter(
    variable=[
    'Trade|Primary Energy|Biomass|Volume',
    'Trade|Primary Energy|Coal|Volume',
    'Trade|Primary Energy|Gas|Volume',
    'Trade|Primary Energy|Oil|Volume',
    'Trade|Secondary Energy|Liquids|Biomass|Volume'
       ],
    scenario=['REF-v2'],)

df_not_on_db_aim.aggregate('Trade|Energy|Biomass & Biofuels',
                           components=['Trade|Primary Energy|Biomass|Volume',
                            'Trade|Secondary Energy|Liquids|Biomass|Volume'
                            ],
                            append=True
                           )

df_not_on_db_aim.rename(variable={
    'Trade|Primary Energy|Coal|Volume':'Trade|Energy|Coal',
    'Trade|Primary Energy|Gas|Volume':'Trade|Energy|Gas',
    'Trade|Primary Energy|Oil|Volume':'Trade|Energy|Oil',
   },
   inplace=True
)

df_not_on_db_aim = df_not_on_db_aim.filter(variable=['Trade|Energy|Biomass & Biofuels',
                                  'Trade|Energy|Coal',
                                  'Trade|Energy|Gas',
                                  'Trade|Energy|Oil',
                                  ])

df_not_on_db_aim.aggregate('Trade|Energy',
                            append=True
                           )

df_aim = pyam.concat([df_aim, df_not_on_db_aim])
# Out:
# [INFO] 10:27:06 - pyam.core: Reading file ..\..\..\data\TOD\model_results\raw\240513_GEO7_AIM.xlsx
# INFO:pyam.core:Reading file ..\..\..\data\TOD\model_results\raw\240513_GEO7_AIM.xlsx

# %%
# Read in IMAGE data that is not yet configured for the IIASA DB
# Or that IMAGE is used for REF as well
df_not_on_db_image = df_image_all.filter(variable=[
    'Average Soil Organic Carbon|Cropland',
    'Average Soil Organic Carbon|Forest',
    'Average Soil Organic Carbon|Grazing Land',
    'Average Soil Organic Carbon|Other Natural Land',
    'Carbon Sequestration|CCS', 
    'Carbon Sequestration|CCS|Biomass', 
    'Carbon Sequestration|CCS|Fossil',
    'Population|Urban',        
    'Carbon stocks',
    'Carbon stocks|Soil',        
    'Carbon stocks|Vegetation',
    'Agricultural Production|Crops|Non-Energy',
    "Population|Clean Cooking Access",
    "Population|Electricity Access",
    "Population|Relying on Solid Fuels",
    'Food Waste',
    'Food Waste|Consumption',
    'Food Waste|Production',   
    'Trade|Biomass & Biofuels',
    'Trade|Coal',
    'Trade|Energy|Volume',
    'Trade|Gas',
    'Trade|Oil',
    'Food Waste|Per capita',
])

print(df_not_on_db_image)

# Capatalize and rename variables
df_not_on_db_image.rename(variable={
    'Carbon stocks':'Carbon Stocks',
    'Carbon stocks|Soil':'Carbon Stocks|Soil',        
    'Carbon stocks|Vegetation':'Carbon Stocks|Vegetation'
}, inplace=True)

df_not_on_db_image.rename(variable={
    'Agricultural Production|Crops|Non-Energy':'Agricultural Production|Non-Energy|Crops',
                                        'Trade|Biomass & Biofuels':'Trade|Energy|Biomass & Biofuels',
                                        'Trade|Coal':'Trade|Energy|Coal',
                                        'Trade|Energy|Volume':'Trade|Energy',
                                        'Trade|Gas':'Trade|Energy|Gas',
                                        'Trade|Oil':'Trade|Energy|Oil'}, inplace=True)

# Read in trade values for IMAGE hist and rename the variables
df_not_on_db_image_hist = df_image_all.filter(variable=['Agricultural Production|Crops|Non-Energy',
                                                  'Trade|Biomass & Biofuels',
                                                  'Trade|Coal',
                                                  'Trade|Energy|Volume',
                                                  'Trade|Gas',
                                                  'Trade|Oil',
                                                  'Average Soil Organic Carbon|Cropland',
                                                    'Average Soil Organic Carbon|Forest',
                                                    'Average Soil Organic Carbon|Grazing Land',
                                                    'Average Soil Organic Carbon|Other Natural Land',
                                                  ], scenario='REF-v2')
print(df_not_on_db_image_hist.filter(variable=['Average Soil Organic Carbon|Cropland',
                                                    'Average Soil Organic Carbon|Forest',
                                                    'Average Soil Organic Carbon|Grazing Land',
                                                    'Average Soil Organic Carbon|Other Natural Land',]))

df_not_on_db_image_hist.rename(variable={'Agricultural Production|Crops|Non-Energy':'Agricultural Production|Non-Energy|Crops',
                                    'Trade|Biomass & Biofuels':'Trade|Energy|Biomass & Biofuels',
                                    'Trade|Coal':'Trade|Energy|Coal',
                                    'Trade|Energy|Volume':'Trade|Energy',
                                    'Trade|Gas':'Trade|Energy|Gas',
                                    'Trade|Oil':'Trade|Energy|Oil'}, inplace=True)


df_image = pyam.concat([df_image, df_not_on_db_image, df_gdp])
df_image_hist = pyam.concat([df_image_hist, df_not_on_db_image_hist])
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : IMAGE 3.3 (1)
#  * scenario : LIFE-TP-v2, REF-v2, TECH-TP-v2 (3)
# Timeseries data coordinates:
#    region   : BRA, CAN, CEU, CHN, EAF, INDIA, INDO, JAP, KOR, ME, ... World (27)
#    variable : Agricultural Production|Crops|Non-Energy, ... Trade|Oil (24)
#    unit     : EJ/yr, GtC, Mt CO2/yr, kcal/cap/day, million, ... tC/ha (7)
#    year     : 2005, 2010, 2015, 2020, 2025, 2030, 2035, 2040, ... 2100 (15)
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : IMAGE 3.3 (1)
#  * scenario : REF-v2 (1)
# Timeseries data coordinates:
#    region   : BRA, CAN, CEU, CHN, EAF, INDIA, INDO, JAP, KOR, ME, ... World (27)
#    variable : Average Soil Organic Carbon|Cropland, ... (4)
#    unit     : tC/ha (1)
#    year     : 2005, 2010, 2015, 2020, 2025, 2030, 2035, 2040, ... 2100 (15)

# %%
weighted_variables = [
    'Food Demand',
    'Food Demand|Crops',
    'Food Demand|Livestock',
    'Yield|Cereal',
    'Yield|Oilcrops',
    'Yield|Sugarcrops',
    'Food Waste|Per Capita',
    'Average Soil Organic Carbon|Cropland',
    'Average Soil Organic Carbon|Forest',
    'Average Soil Organic Carbon|Grazing Land',
    'Average Soil Organic Carbon|Other Natural Land',
]
abs_variables = [value for value in df_image.variable if value not in weighted_variables]

# %%
# Some of the variables are not configured on the iiasa database yet, aggregate here manually (Only a summation)
def compute_UN_groups(df, variables, weight=None):
    df_africa = df.aggregate_region(variables,
                              region='Africa (UN-R5)',
                              subregions=[
                                    'NAF',
                                    'WAF',
                                    'EAF',
                                    'SAF',
                                    'RSAF',
                              ],
                              weight=weight
                              )

    df_asia = df.aggregate_region(variables,
                              region='Asia and the Pacific (UN-R5)',
                              subregions=[
                                'CHN',
                                'INDIA',
                                'INDO',
                                'JAP',
                                'KOR',
                                'ME',
                                'RSAS',
                                'SEAS',
                                'STAN',
                              ],
                              weight=weight
                              )

    df_ee = df.aggregate_region(variables,
                              region='Eastern Europe (UN-R5)',
                              subregions=[
                                    'CEU',
                                    'RUS',
                                    'UKR',
                              ],
                              weight=weight
                              )

    df_latin = df.aggregate_region(variables,
                              region='Latin America and Caribbean (UN-R5)',
                              subregions=[
                                    'BRA',
                                    'MEX',
                                    'RCAM',
                                    'RSAM',
                              ],
                              weight=weight
                              )

    df_we = df.aggregate_region(variables,
                              region='Western Europe and Other States (UN-R5)',
                              subregions=[
                                        'CAN',
                                        'OCE',
                                        'TUR',
                                        'USA',
                                        'WEU',
                              ],
                              weight=weight
                              )
    
    df_world = df.filter(region='World', variable=variables)

    df_un_groups = pyam.concat([df_africa, df_asia, df_ee, df_latin, df_we, df_world])
    return df_un_groups

# Some of the variables are not configured on the iiasa database yet, aggregate here manually (Only a summation)
def compute_UN_groups_aim(df, variables, weight=None):
    
    df_africa = df.aggregate_region(variables,
                              region='Africa (UN-R5)',
                              subregions=[
                                    'XAF',
                                    'XNF',
                              ],
                              weight=weight
                              )

    df_asia = df.aggregate_region(variables,
                              region='Asia and the Pacific (UN-R5)',
                              subregions=[
                                    'CHN',
                                    'IND',
                                    'JPN',
                                    'XSE',
                                    'XSA',
                                    'XME',
                              ],
                              weight=weight
                              )

    df_ee = df.aggregate_region(variables,
                              region='Eastern Europe (UN-R5)',
                              subregions=[
                                    'CIS',
                                    'XER',
                              ],
                              weight=weight
                              )

    df_latin = df.aggregate_region(variables,
                              region='Latin America and Caribbean (UN-R5)',
                              subregions=[
                                    'BRA',
                                    'XLM',
                              ],
                              weight=weight
                              )

    df_we = df.aggregate_region(variables,
                              region='Western Europe and Other States (UN-R5)',
                              subregions=[
                                    'CAN',
                                    'XOC',
                                    'TUR',
                                    'USA',
                                    'XE25', 
                              ],
                              weight=weight
                              )
    
    df_world = df.filter(region='World', variable=variables)

    df_un_groups = pyam.concat([df_africa, df_asia, df_ee, df_latin, df_we, df_world])
    return df_un_groups

# %%
df_image_abs = compute_UN_groups(df_image, abs_variables)
# There are some variables in the IMAGE df that we also need for REF, but not for the variables below, so remove any REF values
df_image_food = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Food Demand','Food Demand|Crops','Food Demand|Livestock','Food Waste|Per Capita'], 'Population')
df_image_yield = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops',], 'Agricultural Production|Non-Energy|Crops')

df_image_soc_cropland = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Average Soil Organic Carbon|Cropland'], 'Land Cover|Cropland')
df_image_soc_grazing = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Average Soil Organic Carbon|Grazing Land'], 'Land Cover|Pasture')
df_image_soc_forest = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Average Soil Organic Carbon|Forest'], 'Land Cover|Forest')
df_image_soc_onl = compute_UN_groups(df_image.filter(scenario='REF-v2', keep=False), ['Average Soil Organic Carbon|Other Natural Land'], 'Land Cover|Other Natural Land') 

df_image = pyam.concat([df_image_abs, df_image_food, df_image_yield,df_image_soc_cropland, df_image_soc_grazing, df_image_soc_forest, df_image_soc_onl])


df_image_hist_abs = compute_UN_groups(df_image_hist, abs_variables)
df_image_hist_food = compute_UN_groups(df_image_hist, ['Food Demand','Food Demand|Crops','Food Demand|Livestock','Food Waste|Per Capita'], 'Population')
df_image_hist_yield = compute_UN_groups(df_image_hist, ['Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops',], 'Agricultural Production|Non-Energy|Crops')
df_image_hist_soc_cropland = compute_UN_groups(df_image_hist, ['Average Soil Organic Carbon|Cropland'], 'Land Cover|Cropland')
df_image_hist_soc_grazing = compute_UN_groups(df_image_hist, ['Average Soil Organic Carbon|Grazing Land'], 'Land Cover|Pasture')
df_image_hist_soc_forest = compute_UN_groups(df_image_hist, ['Average Soil Organic Carbon|Forest'], 'Land Cover|Forest')
df_image_hist_soc_onl = compute_UN_groups(df_image_hist, ['Average Soil Organic Carbon|Other Natural Land'], 'Land Cover|Other Natural Land')

df_image_hist = pyam.concat([df_image_hist_abs, df_image_hist_food, df_image_hist_yield,
                             df_image_hist_soc_cropland, df_image_hist_soc_grazing, df_image_hist_soc_forest, df_image_hist_soc_onl
                             ])
df_image_hist = df_image_hist.filter(variable='Population', keep=False)

# SOC weighted by land cover area


df_aim_abs = compute_UN_groups_aim(df_aim, abs_variables)
df_aim_food = compute_UN_groups_aim(df_aim, ['Food Demand','Food Demand|Crops','Food Demand|Livestock', 'Food Waste|Per Capita'], 'Population')
df_aim_yield = compute_UN_groups_aim(df_aim, ['Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops',], 'Agricultural Production|Non-Energy|Crops')
df_aim = pyam.concat([df_aim_abs, df_aim_food, df_aim_yield,])
df_aim = df_aim.filter(variable='Population', keep=False)

# %%
# Copy Temperature to all regions
for region in [
        'Latin America and Caribbean (UN-R5)',
        'Western Europe and Other States (UN-R5)',
        'Africa (UN-R5)',
        'Asia and the Pacific (UN-R5)',
        'Eastern Europe (UN-R5)',
        ]:
        df_region_image = df_image.filter(variable="Temperature|Global Mean", region='World').rename(region={'World':region})
        df_image = pyam.concat([df_image, df_region_image])
        df_region_image_hist = df_image_hist.filter(variable="Temperature|Global Mean", region='World').rename(region={'World':region})
        df_image_hist = pyam.concat([df_image_hist, df_region_image_hist])
        df_region_aim = df_aim.filter(variable="Temperature|Global Mean", region='World').rename(region={'World':region})
        df_aim = pyam.concat([df_aim, df_region_aim])

# %% [markdown]
# # Aggregate variables

# %%
def aggregate_variables(pyam_df):
    # Create new variables
    pyam_df = pyam_df.rename(mapping={'variable': {'Land Cover|Built-up Area': 'Land Cover|Other',
                                                   }},
                                                   )
    
    pyam_df.multiply('Primary Energy|Nuclear', 1, 'Primary Energy|Other', ignore_units='EJ/yr', append=True)

    # Land Cover|Forest and Other Natural Land
    pyam_df.aggregate("Land Cover|Forest and Other Natural Land", 
                        components=['Land Cover|Forest',
                                    'Land Cover|Other Natural Land'], 
                            append=True)

    # Priamry Energy|Fossil
    pyam_df.aggregate("Primary Energy|Fossil", 
                        components=['Primary Energy|Coal', 
                                'Primary Energy|Oil', 
                                'Primary Energy|Gas',], 
                            append=True)
    
    # Priamry Energy|Fossil|w/ CCS"
    pyam_df.aggregate("Primary Energy|Fossil|w/ CCS", 
                        components=['Primary Energy|Coal|w/ CCS', 
                                'Primary Energy|Oil|w/ CCS', 
                                'Primary Energy|Gas|w/ CCS',], 
                            append=True)
    
    # Priamry Energy|Fossil|w/ CCS"
    pyam_df.aggregate("Primary Energy|Fossil|w/o CCS", 
                        components=['Primary Energy|Coal|w/o CCS', 
                                'Primary Energy|Oil|w/o CCS', 
                                'Primary Energy|Gas|w/o CCS',], 
                            append=True)

    # Share of Non-Biomass Renewables
    pyam_df.divide("Primary Energy|Non-Biomass Renewables", 
                "Primary Energy", 
                "Primary Energy|Non-Biomass Renewables (Fraction)", 
                ignore_units=True, 
                append=True)
    pyam_df.multiply("Primary Energy|Non-Biomass Renewables (Fraction)", 
                100, 
                "Primary Energy|Non-Biomass Renewables (Share)", 
                ignore_units='%', 
                append=True)

    # Agricultural Demand|Crops
    pyam_df.aggregate("Agricultural Demand|Crops", 
                        components=['Agricultural Demand|Energy|Crops', 
                                    'Agricultural Demand|Non-Energy|Crops',
                                    ], 
                            append=True)

    pyam_df.divide("Food Demand|Crops",
                "Food Demand", 
                "Food Demand|Crops (Fraction)", 
                ignore_units=True, 
                append=True)
    pyam_df.multiply("Food Demand|Crops (Fraction)", 
                100, 
                "Food Demand|Crops (Share)", 
                ignore_units='%', 
                append=True)
    
    # Agricultural Production|Crops
    pyam_df.aggregate("Agricultural Production|Crops",
                    components=['Agricultural Production|Non-Energy|Crops',
                                'Agricultural Production|Energy|Crops',],
                    append=True)

    pyam_df.subtract(
        f'Agricultural Production|Crops',
        f'Agricultural Demand|Crops',
        f'Trade|Agriculture|Crops',
        ignore_units='million t DM/yr',
        append=True
    )

    # Remove the regional emissions precursors 
    pyam_df = pyam_df.filter(
        variable=[
        'Emissions|BC', 
        'Emissions|CO', 
        'Emissions|NOx', 
        'Emissions|NH3', 
        'Emissions|OC', 
        'Emissions|Sulfur', 
        'Emissions|VOC',],
        region=[
        'Latin America and Caribbean (UN-R5)',
        'Western Europe and Other States (UN-R5)',
        'Africa (UN-R5)',
        'Asia and the Pacific (UN-R5)',
        'Eastern Europe (UN-R5)',
        ], keep=False)
    
    return pyam_df

# pyam.utils: Formatted data is empty. is because in AIM REF there is no CCS
df_aim = aggregate_variables(df_aim)
df_image = aggregate_variables(df_image)
df_image_hist = aggregate_variables(df_image_hist)
# df_aim_transpaths = aggregate_variables(df_aim_transpaths)
# Out:
# [WARNING] 10:27:32 - pyam.utils: Formatted data is empty.
# WARNING:pyam.utils:Formatted data is empty.
# [WARNING] 10:27:33 - pyam.utils: Formatted data is empty.
# WARNING:pyam.utils:Formatted data is empty.

# %% [markdown]
# # Harmonization of AIM to IMAGE 2020

# %%
# Find the variables that are uploaded by AIM, these should also be harmonized
# The others can be copy pasted to AIM results
# print df_aim variables
print(df_aim.variable)
common_variables = [value for value in df_image.filter(scenario='REF-v2').variable if value in df_aim.variable]

# Reset index for a specific level
# Add variables to df_image_hist_extended df and df_aim and remove from df_not_on_db
# Remove any common data from df_image_hist and concat it with REF data from IMAGE that is present in AIM
# Use IMAGE for emissions
df_image_hist_extended = pyam.concat([df_image_hist.filter(variable=common_variables, keep=False), 
                                      df_image.filter(variable=common_variables, scenario='REF-v2')], 
                                     ignore_meta_conflict=True)

print(df_image_hist_extended.filter(variable='Average Soil Organic Carbon|Cropland'))


# Create a dataframe that contains the method of harmonization per variable
# Only create methods for variables present in AIM
methods = df_image_hist_extended.filter(variable=df_aim.variable).timeseries().reset_index(level='model', drop=True)
# The offset methods ensure internal regional consistency better than the ratio methods
methods['method'] = 'reduce_offset_2080' # 'reduce_ratio_2080' 'constant_ratio' 'constant_offset' 'reduce_offset_2080'
methods_series = methods['method']

# These variables need a different method, manually checked for best performance
agricultural_vars = ['Agricultural Demand',
                    'Agricultural Demand|Energy|Crops',
                    'Agricultural Demand|Crops',
                    'Agricultural Demand|Non-Energy|Livestock',
                    'Agricultural Demand|Non-Energy|Crops',
                    'Agricultural Demand|Non-Energy|Crops|Feed',
                    'Agricultural Demand|Non-Energy|Crops|Food',
                    'Agricultural Demand|Non-Energy|Crops|Other',
                    'Agricultural Production',
                    'Agricultural Production|Energy|Crops',
                    'Agricultural Production|Crops',
                    'Agricultural Production|Non-Energy|Livestock',
                    'Agricultural Production|Non-Energy|Crops'
                    ]

land_cover_vars = ['Land Cover|Other',
                    'Land Cover|Cropland',
                    'Land Cover|Other Natural Land',
                    'Land Cover|Forest',
                    'Land Cover|Forest and Other Natural Land',
                    'Land Cover|Pasture',
                    # 'Average Soil Organic Carbon|Cropland',
                    # 'Average Soil Organic Carbon|Forest',
                    # 'Average Soil Organic Carbon|Grazing Land',
                    # 'Average Soil Organic Carbon|Other Natural Land',
                    ]

yield_vars = ['Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops']

trade_vars = [
    'Trade|Energy',
    'Trade|Energy|Biomass & Biofuels',
    'Trade|Energy|Coal',
    'Trade|Energy|Gas',
    'Trade|Energy|Oil'
]

methods_series.loc[:,:,agricultural_vars + land_cover_vars + yield_vars  + trade_vars,:] = 'constant_offset' # + emission_vars
methods_series
# Out:
# ['Agricultural Demand', 'Agricultural Demand|Crops', 'Agricultural Demand|Energy', 'Agricultural Demand|Energy|Crops', 'Agricultural Demand|Non-Energy|Crops', 'Agricultural Demand|Non-Energy|Crops|Feed', 'Agricultural Demand|Non-Energy|Crops|Food', 'Agricultural Demand|Non-Energy|Crops|Other', 'Agricultural Demand|Non-Energy|Livestock', 'Agricultural Production', 'Agricultural Production|Crops', 'Agricultural Production|Energy|Crops', 'Agricultural Production|Non-Energy|Crops', 'Agricultural Production|Non-Energy|Livestock', 'Emissions|BC', 'Emissions|CH4', 'Emissions|CH4|AFOLU', 'Emissions|CH4|Energy', 'Emissions|CO', 'Emissions|CO2', 'Emissions|CO2|AFOLU', 'Emissions|CO2|Energy', 'Emissions|CO2|Energy and Industrial Processes', 'Emissions|CO2|Energy|Demand|Industry', 'Emissions|CO2|Energy|Demand|Residential', 'Emissions|CO2|Energy|Demand|Transportation', 'Emissions|F-Gases', 'Emissions|Kyoto Gases', 'Emissions|N2O', 'Emissions|N2O|AFOLU', 'Emissions|N2O|Energy', 'Emissions|NH3', 'Emissions|NOx', 'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC', 'Final Energy', 'Final Energy|Electricity', 'Final Energy|Gases', 'Final Energy|Heat', 'Final Energy|Hydrogen', 'Final Energy|Industry', 'Final Energy|Liquids', 'Final Energy|Other Sector', 'Final Energy|Residential and Commercial', 'Final Energy|Solids', 'Final Energy|Transportation', 'Food Demand', 'Food Demand|Crops', 'Food Demand|Crops (Fraction)', 'Food Demand|Crops (Share)', 'Food Demand|Livestock', 'Land Cover|Cropland', 'Land Cover|Forest', 'Land Cover|Forest and Other Natural Land', 'Land Cover|Other', 'Land Cover|Other Natural Land', 'Land Cover|Pasture', 'Primary Energy', 'Primary Energy|Biomass', 'Primary Energy|Biomass|Traditional', 'Primary Energy|Biomass|w/o CCS', 'Primary Energy|Coal', 'Primary Energy|Coal|w/o CCS', 'Primary Energy|Fossil', 'Primary Energy|Fossil|w/o CCS', 'Primary Energy|Gas', 'Primary Energy|Gas|w/o CCS', 'Primary Energy|Hydro', 'Primary Energy|Non-Biomass Renewables', 'Primary Energy|Non-Biomass Renewables (Fraction)', 'Primary Energy|Non-Biomass Renewables (Share)', 'Primary Energy|Nuclear', 'Primary Energy|Oil', 'Primary Energy|Oil|w/o CCS', 'Primary Energy|Other', 'Primary Energy|Solar', 'Primary Energy|Wind', 'Secondary Energy|Electricity', 'Secondary Energy|Electricity|Biomass', 'Secondary Energy|Electricity|Coal', 'Secondary Energy|Electricity|Gas', 'Secondary Energy|Electricity|Hydro', 'Secondary Energy|Electricity|Non-Biomass Renewables', 'Secondary Energy|Electricity|Nuclear', 'Secondary Energy|Electricity|Oil', 'Secondary Energy|Electricity|Solar', 'Secondary Energy|Electricity|Wind', 'Temperature|Global Mean', 'Trade|Agriculture|Crops', 'Trade|Energy', 'Trade|Energy|Biomass & Biofuels', 'Trade|Energy|Coal', 'Trade|Energy|Gas', 'Trade|Energy|Oil', 'Water Consumption', 'Water Consumption|Electricity', 'Water Consumption|Industrial Water', 'Water Consumption|Irrigation', 'Water Consumption|Municipal Water', 'Water Withdrawal', 'Water Withdrawal|Electricity', 'Water Withdrawal|Industrial Water', 'Water Withdrawal|Irrigation', 'Water Withdrawal|Municipal Water', 'Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops']
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : IMAGE 3.3 (1)
#  * scenario : REF-v2 (1)
# Timeseries data coordinates:
#    region   : Africa (UN-R5), Asia and the Pacific (UN-R5), ... World (6)
#    variable : Average Soil Organic Carbon|Cropland (1)
#    unit     : tC/ha (1)
#    year     : 2005, 2010, 2015, 2020, 2025, 2030, 2035, 2040, ... 2100 (15)
# C:\Users\maycocks\AppData\Local\Temp\2\ipykernel_5388\3229055860.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   methods_series.loc[:,:,agricultural_vars + land_cover_vars + yield_vars  + trade_vars,:] = 'constant_offset' # + emission_vars
# scenario  region          variable                              unit
# REF-v2    Africa (UN-R5)  Agricultural Demand                   million t DM/yr       constant_offset
#                           Agricultural Demand|Crops             million t DM/yr       constant_offset
#                           Agricultural Demand|Energy            million t DM/yr    reduce_offset_2080
#                           Agricultural Demand|Energy|Crops      million t DM/yr       constant_offset
#                           Agricultural Demand|Non-Energy|Crops  million t DM/yr       constant_offset
#                                                                                           ...
#           World           Water Withdrawal|Irrigation           km3/yr             reduce_offset_2080
#                           Water Withdrawal|Municipal Water      km3/yr             reduce_offset_2080
#                           Yield|Cereal                          t DM/ha/yr            constant_offset
#                           Yield|Oilcrops                        t DM/ha/yr            constant_offset
#                           Yield|Sugarcrops                      t DM/ha/yr            constant_offset
# Name: method, Length: 607, dtype: object

# %%
# AIM will be harmonized to IMAGE REF historic values
print(df_aim.variable)
hist_to_harmonize = df_image_hist_extended.filter(variable=df_aim.variable).timeseries() # .filter(variable=variable)
df_aim_to_harmonize = df_aim.timeseries() # .filter(variable=variable)

# Remove the model level from index and column names should be strings
df_aim_to_harmonize = df_aim_to_harmonize.reset_index(level='model', drop=True)
df_aim_to_harmonize.columns = df_aim_to_harmonize.columns.astype(str)
hist_to_harmonize = hist_to_harmonize.reset_index(level='model', drop=True)
hist_to_harmonize.columns = hist_to_harmonize.columns.astype(str)

# Harmonize 
h = aneris.harmonize.Harmonizer(df_aim_to_harmonize, hist_to_harmonize, config={'harmonize_year': '2020'})
harmonized = h.harmonize(methods_series) # methods_copy

# Add all necessary index columns
new_level = 'AIM_Harmonized'
df_index = harmonized.index.to_frame()  # Convert the MultiIndex to a DataFrame
df_index['model'] = new_level  # Add the new level
df_index = df_index[['model', 'scenario', 'region', 'variable', 'unit']]
new_index = pd.MultiIndex.from_frame(df_index)  # Create a new MultiIndex with the added level
harmonized.index = new_index

df_harmonized = pyam.IamDataFrame(harmonized)
print(df_harmonized.variable)



# Final Energy|Heat is missing from AIM, but the total on world level is still correct
# Probably no Final Energy|Heat in Africa, so adding 0s is alright
# ALWAYS CHECK IF ADDING NEW VARIABLES!!!
# Out:
# WARNING:root:More history than model reports, adding 0 values scenario  region          variable           unit
# REF-v2    Africa (UN-R5)  Final Energy|Heat  EJ/yr    (REF-v2, Africa (UN-R5), Final Energy|Heat, EJ...
# dtype: object
# ['Agricultural Demand', 'Agricultural Demand|Crops', 'Agricultural Demand|Energy', 'Agricultural Demand|Energy|Crops', 'Agricultural Demand|Non-Energy|Crops', 'Agricultural Demand|Non-Energy|Crops|Feed', 'Agricultural Demand|Non-Energy|Crops|Food', 'Agricultural Demand|Non-Energy|Crops|Other', 'Agricultural Demand|Non-Energy|Livestock', 'Agricultural Production', 'Agricultural Production|Crops', 'Agricultural Production|Energy|Crops', 'Agricultural Production|Non-Energy|Crops', 'Agricultural Production|Non-Energy|Livestock', 'Emissions|BC', 'Emissions|CH4', 'Emissions|CH4|AFOLU', 'Emissions|CH4|Energy', 'Emissions|CO', 'Emissions|CO2', 'Emissions|CO2|AFOLU', 'Emissions|CO2|Energy', 'Emissions|CO2|Energy and Industrial Processes', 'Emissions|CO2|Energy|Demand|Industry', 'Emissions|CO2|Energy|Demand|Residential', 'Emissions|CO2|Energy|Demand|Transportation', 'Emissions|F-Gases', 'Emissions|Kyoto Gases', 'Emissions|N2O', 'Emissions|N2O|AFOLU', 'Emissions|N2O|Energy', 'Emissions|NH3', 'Emissions|NOx', 'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC', 'Final Energy', 'Final Energy|Electricity', 'Final Energy|Gases', 'Final Energy|Heat', 'Final Energy|Hydrogen', 'Final Energy|Industry', 'Final Energy|Liquids', 'Final Energy|Other Sector', 'Final Energy|Residential and Commercial', 'Final Energy|Solids', 'Final Energy|Transportation', 'Food Demand', 'Food Demand|Crops', 'Food Demand|Crops (Fraction)', 'Food Demand|Crops (Share)', 'Food Demand|Livestock', 'Land Cover|Cropland', 'Land Cover|Forest', 'Land Cover|Forest and Other Natural Land', 'Land Cover|Other', 'Land Cover|Other Natural Land', 'Land Cover|Pasture', 'Primary Energy', 'Primary Energy|Biomass', 'Primary Energy|Biomass|Traditional', 'Primary Energy|Biomass|w/o CCS', 'Primary Energy|Coal', 'Primary Energy|Coal|w/o CCS', 'Primary Energy|Fossil', 'Primary Energy|Fossil|w/o CCS', 'Primary Energy|Gas', 'Primary Energy|Gas|w/o CCS', 'Primary Energy|Hydro', 'Primary Energy|Non-Biomass Renewables', 'Primary Energy|Non-Biomass Renewables (Fraction)', 'Primary Energy|Non-Biomass Renewables (Share)', 'Primary Energy|Nuclear', 'Primary Energy|Oil', 'Primary Energy|Oil|w/o CCS', 'Primary Energy|Other', 'Primary Energy|Solar', 'Primary Energy|Wind', 'Secondary Energy|Electricity', 'Secondary Energy|Electricity|Biomass', 'Secondary Energy|Electricity|Coal', 'Secondary Energy|Electricity|Gas', 'Secondary Energy|Electricity|Hydro', 'Secondary Energy|Electricity|Non-Biomass Renewables', 'Secondary Energy|Electricity|Nuclear', 'Secondary Energy|Electricity|Oil', 'Secondary Energy|Electricity|Solar', 'Secondary Energy|Electricity|Wind', 'Temperature|Global Mean', 'Trade|Agriculture|Crops', 'Trade|Energy', 'Trade|Energy|Biomass & Biofuels', 'Trade|Energy|Coal', 'Trade|Energy|Gas', 'Trade|Energy|Oil', 'Water Consumption', 'Water Consumption|Electricity', 'Water Consumption|Industrial Water', 'Water Consumption|Irrigation', 'Water Consumption|Municipal Water', 'Water Withdrawal', 'Water Withdrawal|Electricity', 'Water Withdrawal|Industrial Water', 'Water Withdrawal|Irrigation', 'Water Withdrawal|Municipal Water', 'Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops']
# c:\PBLprogs\miniforge3\lib\site-packages\aneris\methods.py:377: RuntimeWarning: invalid value encountered in scalar divide
#   return np.abs(np.std(x) / np.mean(x))
# INFO:root:Harmonizing with constant_offset
# INFO:root:Harmonizing with reduce_offset_2080
# ['Agricultural Demand', 'Agricultural Demand|Crops', 'Agricultural Demand|Energy', 'Agricultural Demand|Energy|Crops', 'Agricultural Demand|Non-Energy|Crops', 'Agricultural Demand|Non-Energy|Crops|Feed', 'Agricultural Demand|Non-Energy|Crops|Food', 'Agricultural Demand|Non-Energy|Crops|Other', 'Agricultural Demand|Non-Energy|Livestock', 'Agricultural Production', 'Agricultural Production|Crops', 'Agricultural Production|Energy|Crops', 'Agricultural Production|Non-Energy|Crops', 'Agricultural Production|Non-Energy|Livestock', 'Emissions|BC', 'Emissions|CH4', 'Emissions|CH4|AFOLU', 'Emissions|CH4|Energy', 'Emissions|CO', 'Emissions|CO2', 'Emissions|CO2|AFOLU', 'Emissions|CO2|Energy', 'Emissions|CO2|Energy and Industrial Processes', 'Emissions|CO2|Energy|Demand|Industry', 'Emissions|CO2|Energy|Demand|Residential', 'Emissions|CO2|Energy|Demand|Transportation', 'Emissions|Kyoto Gases', 'Emissions|N2O', 'Emissions|N2O|AFOLU', 'Emissions|N2O|Energy', 'Emissions|NH3', 'Emissions|NOx', 'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC', 'Final Energy', 'Final Energy|Electricity', 'Final Energy|Gases', 'Final Energy|Heat', 'Final Energy|Hydrogen', 'Final Energy|Industry', 'Final Energy|Liquids', 'Final Energy|Other Sector', 'Final Energy|Residential and Commercial', 'Final Energy|Solids', 'Final Energy|Transportation', 'Food Demand', 'Food Demand|Crops', 'Food Demand|Crops (Fraction)', 'Food Demand|Crops (Share)', 'Food Demand|Livestock', 'Land Cover|Cropland', 'Land Cover|Forest', 'Land Cover|Forest and Other Natural Land', 'Land Cover|Other', 'Land Cover|Other Natural Land', 'Land Cover|Pasture', 'Primary Energy', 'Primary Energy|Biomass', 'Primary Energy|Biomass|Traditional', 'Primary Energy|Biomass|w/o CCS', 'Primary Energy|Coal', 'Primary Energy|Coal|w/o CCS', 'Primary Energy|Fossil', 'Primary Energy|Fossil|w/o CCS', 'Primary Energy|Gas', 'Primary Energy|Gas|w/o CCS', 'Primary Energy|Hydro', 'Primary Energy|Non-Biomass Renewables', 'Primary Energy|Non-Biomass Renewables (Fraction)', 'Primary Energy|Non-Biomass Renewables (Share)', 'Primary Energy|Nuclear', 'Primary Energy|Oil', 'Primary Energy|Oil|w/o CCS', 'Primary Energy|Other', 'Primary Energy|Solar', 'Primary Energy|Wind', 'Secondary Energy|Electricity', 'Secondary Energy|Electricity|Biomass', 'Secondary Energy|Electricity|Coal', 'Secondary Energy|Electricity|Gas', 'Secondary Energy|Electricity|Hydro', 'Secondary Energy|Electricity|Non-Biomass Renewables', 'Secondary Energy|Electricity|Nuclear', 'Secondary Energy|Electricity|Oil', 'Secondary Energy|Electricity|Solar', 'Secondary Energy|Electricity|Wind', 'Temperature|Global Mean', 'Trade|Agriculture|Crops', 'Trade|Energy', 'Trade|Energy|Biomass & Biofuels', 'Trade|Energy|Coal', 'Trade|Energy|Gas', 'Trade|Energy|Oil', 'Water Consumption', 'Water Consumption|Electricity', 'Water Consumption|Industrial Water', 'Water Consumption|Irrigation', 'Water Consumption|Municipal Water', 'Water Withdrawal', 'Water Withdrawal|Electricity', 'Water Withdrawal|Industrial Water', 'Water Withdrawal|Irrigation', 'Water Withdrawal|Municipal Water', 'Yield|Cereal', 'Yield|Oilcrops', 'Yield|Sugarcrops']

# %% [markdown]
# # Concat AIM Harmonized REF to IMAGE

# %%
df_soc = df_image_hist_extended.filter(variable=['Average Soil Organic Carbon|Cropland',
                                                  'Average Soil Organic Carbon|Forest',
                                                  'Average Soil Organic Carbon|Grazing Land',
                                                  'Average Soil Organic Carbon|Other Natural Land',])
df = pyam.concat([df_harmonized, df_image, df_soc])
df.divide('Population|Urban', ['Population'], 'Population|Urban (Share)', append=True)
df.convert_unit('', '%', inplace=True)
df = df.filter(year=[2000, 2010, 2020, 2030, 2040, 2050,
                     2060, 2070, 2080, 2090, 2100])
df = df.rename(scenario={
    'REF-v2':'REF', 
    'TECH-TP-v2':'TECH-TP', 
    'LIFE-TP-v2':'LIFE-TP'})

# To see what variables for the REF scenario are now from IMAGE
df.filter(model='IMAGE 3.3', scenario='REF').variable

print(df.variable)
# Out:
# ['Agricultural Demand', 'Agricultural Demand|Crops', 'Agricultural Demand|Energy', 'Agricultural Demand|Energy|Crops', 'Agricultural Demand|Energy|Residues', 'Agricultural Demand|Non-Energy|Crops', 'Agricultural Demand|Non-Energy|Crops|Feed', 'Agricultural Demand|Non-Energy|Crops|Food', 'Agricultural Demand|Non-Energy|Crops|Other', 'Agricultural Demand|Non-Energy|Livestock', 'Agricultural Demand|Non-Energy|Livestock|Food', 'Agricultural Production', 'Agricultural Production|Crops', 'Agricultural Production|Crops|Non-Energy|Maize', 'Agricultural Production|Crops|Non-Energy|Rice', 'Agricultural Production|Crops|Non-Energy|Soybeans', 'Agricultural Production|Crops|Non-Energy|Wheat', 'Agricultural Production|Energy|Crops', 'Agricultural Production|Non-Energy|Crops', 'Agricultural Production|Non-Energy|Livestock', 'Average Soil Organic Carbon|Cropland', 'Average Soil Organic Carbon|Forest', 'Average Soil Organic Carbon|Grazing Land', 'Average Soil Organic Carbon|Other Natural Land', 'Carbon Sequestration|CCS', 'Carbon Sequestration|CCS|Biomass', 'Carbon Sequestration|CCS|Fossil', 'Carbon Sequestration|Direct Air Capture', 'Carbon Stocks', 'Carbon Stocks|Soil', 'Carbon Stocks|Vegetation', 'Emissions|BC', 'Emissions|CH4', 'Emissions|CH4|AFOLU', 'Emissions|CH4|Energy', 'Emissions|CO', 'Emissions|CO2', 'Emissions|CO2|AFOLU', 'Emissions|CO2|Energy', 'Emissions|CO2|Energy and Industrial Processes', 'Emissions|CO2|Energy|Demand|Industry', 'Emissions|CO2|Energy|Demand|Residential', 'Emissions|CO2|Energy|Demand|Transportation', 'Emissions|CO2|Industrial Processes', 'Emissions|F-Gases', 'Emissions|Kyoto Gases', 'Emissions|N2O', 'Emissions|N2O|AFOLU', 'Emissions|N2O|Energy', 'Emissions|NH3', 'Emissions|NOx', 'Emissions|OC', 'Emissions|Sulfur', 'Emissions|VOC', 'Final Energy', 'Final Energy|Electricity', 'Final Energy|Gases', 'Final Energy|Heat', 'Final Energy|Hydrogen', 'Final Energy|Industry', 'Final Energy|Liquids', 'Final Energy|Other Sector', 'Final Energy|Residential and Commercial', 'Final Energy|Solids', 'Final Energy|Transportation', 'Food Demand', 'Food Demand|Crops', 'Food Demand|Crops (Fraction)', 'Food Demand|Crops (Share)', 'Food Demand|Livestock', 'Food Waste', 'Food Waste|Consumption', 'Food Waste|Per capita', 'Food Waste|Production', 'GDP|MER', 'GDP|PPP', 'GDP|PPP|Per Capita', 'Land Cover|Cropland', 'Land Cover|Forest', 'Land Cover|Forest and Other Natural Land', 'Land Cover|Other', 'Land Cover|Other Natural Land', 'Land Cover|Pasture', 'Population', 'Population|Clean Cooking Access', 'Population|Electricity Access', 'Population|Relying on Solid Fuels', 'Population|Urban', 'Population|Urban (Share)', 'Primary Energy', 'Primary Energy|Biomass', 'Primary Energy|Biomass|Traditional', 'Primary Energy|Biomass|w/ CCS', 'Primary Energy|Biomass|w/o CCS', 'Primary Energy|Coal', 'Primary Energy|Coal|w/ CCS', 'Primary Energy|Coal|w/o CCS', 'Primary Energy|Fossil', 'Primary Energy|Fossil|w/ CCS', 'Primary Energy|Fossil|w/o CCS', 'Primary Energy|Gas', 'Primary Energy|Gas|w/ CCS', 'Primary Energy|Gas|w/o CCS', 'Primary Energy|Hydro', 'Primary Energy|Non-Biomass Renewables', 'Primary Energy|Non-Biomass Renewables (Fraction)', 'Primary Energy|Non-Biomass Renewables (Share)', 'Primary Energy|Nuclear', 'Primary Energy|Oil', 'Primary Energy|Oil|w/ CCS', 'Primary Energy|Oil|w/o CCS', 'Primary Energy|Other', 'Primary Energy|Solar', 'Primary Energy|Wind', 'Secondary Energy|Electricity', 'Secondary Energy|Electricity|Biomass', 'Secondary Energy|Electricity|Coal', 'Secondary Energy|Electricity|Gas', 'Secondary Energy|Electricity|Hydro', 'Secondary Energy|Electricity|Non-Biomass Renewables', 'Secondary Energy|Electricity|Nuclear', 'Secondary Energy|Electricity|Oil', 'Secondary Energy|Electricity|Solar', 'Secondary Energy|Electricity|Wind', 'Temperature|Global Mean', 'Trade|Agriculture|Crops', 'Trade|Energy', 'Trade|Energy|Biomass & Biofuels', 'Trade|Energy|Coal', 'Trade|Energy|Gas', 'Trade|Energy|Oil', 'Water Consumption', 'Water Consumption|Electrici ...

# %%
print(df.filter(variable='Average Soil Organic Carbon|Cropland'))
# Out:
# <class 'pyam.core.IamDataFrame'>
# Index:
#  * model    : IMAGE 3.3 (1)
#  * scenario : LIFE-TP, REF, TECH-TP (3)
# Timeseries data coordinates:
#    region   : Africa (UN-R5), Asia and the Pacific (UN-R5), ... World (6)
#    variable : Average Soil Organic Carbon|Cropland (1)
#    unit     : tC/ha (1)
#    year     : 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, ... 2100 (10)

# %% [markdown]
# # Check Regional Consistency

# %%
np_isclose_args = {
    "equal_nan": True,
    "rtol": 0.001,
    "atol": 1e-05,
}

harmonized_inconsistency = df.filter(model='AIM_Harmonized').check_internal_consistency(**np_isclose_args)
harmonized_inconsistency = harmonized_inconsistency.rename(columns={'region':'region_total', 'subregions':'subregions_total'})[['region_total', 'subregions_total']]
harmonized_inconsistency = harmonized_inconsistency.dropna()
df_unstacked = harmonized_inconsistency.unstack(level='year')

df_stacked = df_unstacked.stack(level=0)
# Adjust the column names for better readability
df_stacked.columns = [f'{year}' for year in df_stacked.columns]
df_stacked = df_stacked.rename_axis(index={None: 'totals'})
df_stacked = df_stacked.reset_index()
# The aggregated fraction and shares variables will not be aggregates of the subregions
df_stacked = df_stacked[~df_stacked['unit'].isin(['%', 'unknown', 'kcal/cap/day', '°C', 't DM/ha/yr'])]
df_stacked
# Out:
# [INFO] 10:27:54 - pyam.core: `Agricultural Demand` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Agricultural Demand` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Crops' because it has no components.
# [INFO] 10:27:54 - pyam.core: `Agricultural Demand|Energy` - 48 of 54 rows are not aggregates of components
# INFO:pyam.core:`Agricultural Demand|Energy` - 48 of 54 rows are not aggregates of components
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Energy|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Energy|Crops' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Feed' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Feed' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Food' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Food' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Other' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Non-Energy|Crops|Other' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Demand|Non-Energy|Livestock' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Demand|Non-Energy|Livestock' because it has no components.
# [INFO] 10:27:54 - pyam.core: `Agricultural Production` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Agricultural Production` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Production|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Production|Crops' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Production|Energy|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Production|Energy|Crops' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Production|Non-Energy|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Production|Non-Energy|Crops' because it has no components.
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Agricultural Production|Non-Energy|Livestock' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Agricultural Production|Non-Energy|Livestock' because it has no components.
# [INFO] 10:27:54 - pyam.core: `Emissions|CH4` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Emissions|CH4` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:54 - pyam.aggregation: Cannot aggregate variable 'Emissions|CH4|AFOLU' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CH4|AFOLU' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CH4|Energy' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CH4|Energy' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Emissions|CO2` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Emissions|CO2` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|AFOLU' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|AFOLU' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|Energy' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|Energy' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|Energy and Industrial Processes' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|Energy and Industrial Processes' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Emissions|CO2|Energy and Industrial Processes` - 6 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Emissions|CO2|Energy and Industrial Processes` - 6 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Industry' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Industry' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Residential' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Residential' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Transportation' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO2|Energy|Demand|Transportation' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|Kyoto Gases' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|Kyoto Gases' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Emissions|N2O` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Emissions|N2O` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|N2O|AFOLU' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|N2O|AFOLU' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Emissions|N2O|Energy' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|N2O|Energy' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Final Energy` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Final Energy` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Electricity' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Electricity' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Gases' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Gases' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Heat' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Heat' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Hydrogen' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Hydrogen' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Industry' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Industry' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Liquids' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Liquids' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Other Sector' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Other Sector' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Residential and Commercial' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Residential and Commercial' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Solids' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Solids' because it has no components.
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Final Energy|Transportation' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Final Energy|Transportation' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Food Demand` - 108 of 162 rows are not aggregates of components
# INFO:pyam.core:`Food Demand` - 108 of 162 rows are not aggregates of components
# [INFO] 10:27:55 - pyam.core: `Food Demand` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Food Demand` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Food Demand|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Food Demand|Crops' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Food Demand|Crops` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Food Demand|Crops` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Food Demand|Crops (Fraction)' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Food Demand|Crops (Fraction)' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Food Demand|Crops (Fraction)` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Food Demand|Crops (Fraction)` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Food Demand|Crops (Share)' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Food Demand|Crops (Share)' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Food Demand|Crops (Share)` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Food Demand|Crops (Share)` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Food Demand|Livestock' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Food Demand|Livestock' because it has no components.
# [INFO] 10:27:55 - pyam.core: `Food Demand|Livestock` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Food Demand|Livestock` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:55 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Cropland' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Cropland' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Forest' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Forest' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Forest and Other Natural Land' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Forest and Other Natural Land' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Other' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Other' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Other Natural Land' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Other Natural Land' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Land Cover|Pasture' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Land Cover|Pasture' because it has no components.
# [INFO] 10:27:56 - pyam.core: `Primary Energy` - 162 of 162 rows are not aggregates of components
# INFO:pyam.core:`Primary Energy` - 162 of 162 rows are not aggregates of components
# [INFO] 10:27:56 - pyam.core: `Primary Energy|Biomass` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Primary Energy|Biomass` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Biomass|Traditional' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Biomass|Traditional' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Biomass|w/o CCS' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Biomass|w/o CCS' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Coal|w/o CCS' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Coal|w/o CCS' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Fossil|w/o CCS' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Fossil|w/o CCS' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Gas|w/o CCS' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Gas|w/o CCS' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Hydro' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Hydro' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables (Fraction)' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables (Fraction)' because it has no components.
# [INFO] 10:27:56 - pyam.core: `Primary Energy|Non-Biomass Renewables (Fraction)` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Primary Energy|Non-Biomass Renewables (Fraction)` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables (Share)' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Non-Biomass Renewables (Share)' because it has no components.
# [INFO] 10:27:56 - pyam.core: `Primary Energy|Non-Biomass Renewables (Share)` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Primary Energy|Non-Biomass Renewables (Share)` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Nuclear' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Nuclear' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Oil|w/o CCS' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Oil|w/o CCS' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Other' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Other' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Solar' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Solar' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Primary Energy|Wind' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Primary Energy|Wind' because it has no components.
# [INFO] 10:27:56 - pyam.core: `Secondary Energy|Electricity` - 54 of 54 rows are not aggregates of components
# INFO:pyam.core:`Secondary Energy|Electricity` - 54 of 54 rows are not aggregates of components
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Biomass' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Biomass' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Coal' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Coal' because it has no components.
# [INFO] 10:27:56 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Gas' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Gas' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Hydro' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Hydro' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Non-Biomass Renewables' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Non-Biomass Renewables' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Nuclear' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Nuclear' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Secondary Energy|Electricity|Nuclear` - 4 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Secondary Energy|Electricity|Nuclear` - 4 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Oil' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Oil' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Secondary Energy|Electricity|Oil` - 3 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Secondary Energy|Electricity|Oil` - 3 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Solar' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Solar' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Secondary Energy|Electricity|Wind' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Secondary Energy|Electricity|Wind' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Temperature|Global Mean' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Temperature|Global Mean' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Temperature|Global Mean` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Temperature|Global Mean` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Trade|Agriculture|Crops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Trade|Agriculture|Crops' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Trade|Agriculture|Crops` - 8 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Agriculture|Crops` - 8 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.core: `Trade|Energy` - 8 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Energy` - 8 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Trade|Energy|Biomass & Biofuels' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Trade|Energy|Biomass & Biofuels' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Trade|Energy|Biomass & Biofuels` - 5 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Energy|Biomass & Biofuels` - 5 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Trade|Energy|Coal' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Trade|Energy|Coal' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Trade|Energy|Coal` - 7 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Energy|Coal` - 7 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Trade|Energy|Gas' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Trade|Energy|Gas' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Trade|Energy|Gas` - 7 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Energy|Gas` - 7 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Trade|Energy|Oil' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Trade|Energy|Oil' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Trade|Energy|Oil` - 4 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Trade|Energy|Oil` - 4 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.core: `Water Consumption` - 47 of 54 rows are not aggregates of components
# INFO:pyam.core:`Water Consumption` - 47 of 54 rows are not aggregates of components
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Consumption|Electricity' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Consumption|Electricity' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Consumption|Industrial Water' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Consumption|Industrial Water' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Consumption|Irrigation' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Consumption|Irrigation' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Consumption|Municipal Water' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Consumption|Municipal Water' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Water Withdrawal` - 48 of 54 rows are not aggregates of components
# INFO:pyam.core:`Water Withdrawal` - 48 of 54 rows are not aggregates of components
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Withdrawal|Electricity' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Withdrawal|Electricity' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Withdrawal|Industrial Water' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Withdrawal|Industrial Water' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Withdrawal|Irrigation' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Withdrawal|Irrigation' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Water Withdrawal|Municipal Water' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Water Withdrawal|Municipal Water' because it has no components.
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Yield|Cereal' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Yield|Cereal' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Yield|Cereal` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Yield|Cereal` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Yield|Oilcrops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Yield|Oilcrops' because it has no components.
# [INFO] 10:27:57 - pyam.core: `Yield|Oilcrops` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Yield|Oilcrops` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:57 - pyam.aggregation: Cannot aggregate variable 'Yield|Sugarcrops' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Yield|Sugarcrops' because it has no components.
# [INFO] 10:27:58 - pyam.core: `Yield|Sugarcrops` - 9 of 9 rows are not aggregates of subregions
# INFO:pyam.core:`Yield|Sugarcrops` - 9 of 9 rows are not aggregates of subregions
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|BC' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|BC' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|BC' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|BC' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|CO' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|CO' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|NH3' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|NH3' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|NH3' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|NH3' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|NOx' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|NOx' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|NOx' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|NOx' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|OC' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|OC' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|OC' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|OC' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|Sulfur' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|Sulfur' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|Sulfur' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|Sulfur' to 'World' because it does not exist in any subregion.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|VOC' because it has no components.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|VOC' because it has no components.
# [INFO] 10:27:58 - pyam.aggregation: Cannot aggregate variable 'Emissions|VOC' to 'World' because it does not exist in any subregion.
# INFO:pyam.aggregation:Cannot aggregate variable 'Emissions|VOC' to 'World' because it does not exist in any subregion.
# C:\Users\maycocks\AppData\Local\Temp\2\ipykernel_5388\3275771834.py:12: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked = df_unstacked.stack(level=0)
#              model scenario region  \
# 0   AIM_Harmonized      REF  World
# 1   AIM_Harmonized      REF  World
# 16  AIM_Harmonized      REF  World
# 17  AIM_Harmonized      REF  World
# 18  AIM_Harmonized      REF  World
# 19  AIM_Harmonized      REF  World
# 22  AIM_Harmonized      REF  World
# 23  AIM_Harmonized      REF  World
# 24  AIM_Harmonized      REF  World
# 25  AIM_Harmonized      REF  World
# 26  AIM_Harmonized      REF  World
# 27  AIM_Harmonized      REF  World
# 28  AIM_Harmonized      REF  World
# 29  AIM_Harmonized      REF  World
# 30  AIM_Harmonized      REF  World
# 31  AIM_Harmonized      REF  World
# 32  AIM_Harmonized      REF  World
# 33  AIM_Harmonized      REF  World
#
#                                          variable             unit  \
# 0   Emissions|CO2|Energy and Industrial Processes        Mt CO2/yr
# 1   Emissions|CO2|Energy and Industrial Processes        Mt CO2/yr
# 16           Secondary Energy|Electricity|Nuclear            EJ/yr
# 17           Secondary Energy|Electricity|Nuclear            EJ/yr
# 18               Secondary Energy|Electricity|Oil            EJ/yr
# 19               Secondary Energy|Electricity|Oil            EJ/yr
# 22                        Trade|Agriculture|Crops  million t DM/yr
# 23                        Trade|Agriculture|Crops  million t DM/yr
# 24                                   Trade|Energy            EJ/yr
# 25                                   Trade|Energy            EJ/yr
# 26                Trade|Energy|Biomass & Biofuels            EJ/yr
# 27                Trade|Energy|Biomass & Biofuels            EJ/yr
# 28                              Trade|Energy|Coal            EJ/yr
# 29                              Trade|Energy|Coal            EJ/yr
# 30                               Trade|Energy|Gas            EJ/yr
# 31                               Trade|Energy|Gas            EJ/yr
# 32                               Trade|Energy|Oil            EJ/yr
# 33                               Trade|Energy|Oil            EJ/yr
#
#               totals          2020          2030          2040          2050  \
# 0       region_total  36894.960938  47329.901781  52172.324425  54360.399269
# 1   subregions_total  35897.380066  46498.584655  51507.270544  53861.608833
# 16      region_total           NaN      7.049134      4.582987      2.403640
# 17  subregions_total           NaN      7.038118      4.574654      2.398691
# 18      region_total           NaN           NaN           NaN           NaN
# 19  subregions_total           NaN           NaN           NaN           NaN
# 22      region_total      0.000000     -0.016200     -0.090700     -0.119300
# 23  subregions_total     -0.000759     -0.016732     -0.090906     -0.119479
# 24      region_total           NaN      0.007000      0.009200      0.011900
# 25  subregions_total           NaN      0.007102      0.009602      0.012002
# 26      region_total           NaN      0.000000           NaN      0.000000
# 27  subregions_total           NaN      0.000200           NaN      0.000100
# 28      region_total           NaN      0.007000      0.009200      0.011900
# 29  subregions_total           NaN      0.006801      0.009501      0.011801
# 30      region_total           NaN           NaN      0.000000      0.000000
# 31  subregions_total           NaN           NaN     -0.000098      0.000102
# 32      region_total           NaN      0.000000      0.000000           NaN
# 33  subregions_total           NaN      0.000100      0.000200           NaN
#
#             2060          2070      2080      2090      2100
# 0   59057.862313  63209.808756       NaN       NaN       NaN
# 1   58725.335422  63043.545311       NaN       NaN       NaN
# 16      1.943794           NaN       NaN       NaN       NaN
# 17      1.941527           NaN       NaN       NaN       NaN
# 18           NaN           NaN  0.020900  0.023700  0.025600
# 19           NaN           NaN  0.021100  0.023800  0.025700
# 22     -0.101800           NaN -0.023200  0.003800  0.027100
# 23     -0.101953           NaN -0.023700  0.003600  0.027200
# 24      0.014700      0.019200  0.015500  0.011900  0.005900
# 25      0.014902      0.019502  0.015902  0.012402  0.006402
# 26           NaN      0.000000  0.000000  0.000000       NaN
# 27           NaN      0.000200 -0.000100  0.000100       NaN
# 28      0.014700           NaN  0.015500  0.011900  0.005900
# 29      0.014801           NaN  0.015601  0.012001  0.006101
# 30      0.000000      0.000000  0.000000  0.000000  0.000000
# 31      0.000102      0.000102  0.000302  0.000302  0.000202
# 32           NaN           NaN  0.000000       NaN  0.000000
# 33           NaN           NaN  0.000100       NaN  0.000100

# %%
# Variables that will be shared and what topic they belong to
to_share_vars_topics = {
    'Agricultural Demand': 'Land',
    'Agricultural Demand|Crops': 'Land',
    'Agricultural Demand|Energy': 'Land',
    'Agricultural Demand|Energy|Crops': 'Land',
    'Agricultural Demand|Non-Energy|Crops|Feed': 'Land',
    'Agricultural Demand|Non-Energy|Crops|Food': 'Land',
    'Agricultural Demand|Non-Energy|Crops|Other': 'Land',
    'Agricultural Demand|Non-Energy|Livestock': 'Land',
    'Agricultural Production': 'Land',
    'Agricultural Production|Crops': 'Land',
    'Agricultural Production|Energy|Crops': 'Land',
    'Agricultural Production|Non-Energy|Crops': 'Land',
    'Agricultural Production|Non-Energy|Livestock': 'Land',
    'Average Soil Organic Carbon|Cropland': 'Land',
    'Average Soil Organic Carbon|Forest': 'Land',
    'Average Soil Organic Carbon|Grazing Land': 'Land',
    'Average Soil Organic Carbon|Other Natural Land': 'Land',
    'Carbon Sequestration|CCS': 'Emissions',
    'Carbon Sequestration|CCS|Biomass': 'Emissions',
    'Carbon Sequestration|CCS|Fossil': 'Emissions',
    'Carbon Stocks': 'Land',
    'Carbon Stocks|Soil': 'Land',
    'Carbon Stocks|Vegetation': 'Land',
    'Emissions|CH4': 'Emissions',
    'Emissions|CH4|AFOLU': 'Emissions',
    'Emissions|CH4|Energy': 'Emissions',
    'Emissions|CO2': 'Emissions',
    'Emissions|CO2|AFOLU': 'Emissions',
    'Emissions|CO2|Energy': 'Emissions',
    'Emissions|Kyoto Gases': 'Emissions',
    'Emissions|N2O': 'Emissions',
    'Emissions|N2O|AFOLU': 'Emissions',
    'Emissions|N2O|Energy': 'Emissions',
    'Emissions|BC':'Emissions', 
    'Emissions|CO':'Emissions', 
    'Emissions|NOx':'Emissions', 
    'Emissions|NH3':'Emissions', 
    'Emissions|OC':'Emissions', 
    'Emissions|Sulfur':'Emissions', 
    'Emissions|VOC':'Emissions',
    'Food Demand|Crops (Share)': 'Food',
    'GDP|PPP': 'Macro_Economy',
    'GDP|PPP|Per Capita': 'Macro_Economy',
    'Land Cover|Cropland': 'Land',
    'Land Cover|Other Natural Land': 'Land',
    'Land Cover|Forest and Other Natural Land': 'Land',
    'Land Cover|Forest': 'Land',
    'Land Cover|Other': 'Land',
    'Land Cover|Pasture': 'Land',
    'Population': 'Macro_Economy',
    'Population|Urban (Share)': 'Macro_Economy',
    'Primary Energy': 'Energy',
    'Primary Energy|Biomass': 'Energy',
    'Primary Energy|Biomass|w/ CCS': 'Energy',
    'Primary Energy|Biomass|w/o CCS': 'Energy',
    'Primary Energy|Coal': 'Energy',
    'Primary Energy|Coal|w/ CCS': 'Energy',
    'Primary Energy|Coal|w/o CCS': 'Energy',
    'Primary Energy|Fossil': 'Energy',
    'Primary Energy|Fossil|w/ CCS': 'Energy',
    'Primary Energy|Fossil|w/o CCS': 'Energy',
    'Primary Energy|Gas': 'Energy',
    'Primary Energy|Gas|w/ CCS': 'Energy',
    'Primary Energy|Gas|w/o CCS': 'Energy',
    'Primary Energy|Non-Biomass Renewables': 'Energy',
    'Primary Energy|Non-Biomass Renewables (Share)': 'Energy',
    'Primary Energy|Oil': 'Energy',
    'Primary Energy|Oil|w/ CCS': 'Energy',
    'Primary Energy|Oil|w/o CCS': 'Energy',
    'Primary Energy|Other': 'Energy',
    'Water Withdrawal': 'Water',
    'Water Withdrawal|Electricity': 'Water',
    'Water Withdrawal|Industrial Water': 'Water',
    'Water Withdrawal|Irrigation': 'Water',
    'Water Withdrawal|Municipal Water': 'Water',
    'Agricultural Demand|Non-Energy|Crops': 'Land',
    'Agricultural Production|Non-Energy|Crops': 'Land',
    'Final Energy': 'Energy',
    'Final Energy|Electricity': 'Energy',
    'Final Energy|Industry': 'Energy',
    'Final Energy|Other Sector': 'Energy',
    'Final Energy|Residential and Commercial': 'Energy',
    'Final Energy|Transportation': 'Energy',
    'Primary Energy|Solar': 'Energy',
    'Primary Energy|Wind': 'Energy',
    'Primary Energy|Hydro': 'Energy',
    'Primary Energy|Nuclear': 'Energy',
    'Water Consumption': 'Water',
    'Population|Clean Cooking Access': 'Socio_Economics',
    'Population|Electricity Access': 'Socio_Economics',
    'Population|Relying on Solid Fuels': 'Socio_Economics',
    'Temperature|Global Mean': 'Climate',
    'Primary Energy|Biomass|Traditional': 'Energy',
    'Carbon stocks': 'Land',
    'Carbon stocks|Soil': 'Land',
    'Carbon stocks|Vegetation': 'Land',
    'Food Waste': 'Food',
    'Food Waste|Consumption': 'Food',
    'Food Waste|Per capita': 'Food',
    'Food Waste|Production': 'Food',
    'Food Demand': 'Food',
    'Food Demand|Crops': 'Food',
    'Food Demand|Livestock': 'Food',
    'Yield|Cereal':'Land',
    'Trade|Agriculture|Crops':'Land',
    'Trade|Energy':'Energy',
    'Trade|Energy|Biomass & Biofuels':'Energy',
    'Trade|Energy|Coal':'Energy',
    'Trade|Energy|Gas':'Energy',
    'Trade|Energy|Oil':'Energy',
    'Secondary Energy|Electricity':'Energy',
    'Secondary Energy|Electricity|Biomass':'Energy',
    'Secondary Energy|Electricity|Coal':'Energy',
    'Secondary Energy|Electricity|Gas':'Energy',
    'Secondary Energy|Electricity|Non-Biomass Renewables':'Energy',
    'Secondary Energy|Electricity|Nuclear':'Energy',
    'Secondary Energy|Electricity|Oil':'Energy',
    'Secondary Energy|Electricity|Hydro':'Energy',
    'Secondary Energy|Electricity|Other':'Energy',
    'Secondary Energy|Electricity|Solar':'Energy',
    'Secondary Energy|Electricity|Wind':'Energy',
    'Final Energy|Hydrogen':'Energy',
    'Final Energy|Heat':'Energy',
    'Final Energy|Gases':'Energy',
    'Final Energy|Liquids':'Energy',
    'Final Energy|Solids':'Energy',
    'Emissions|CO2|Energy|Demand|Residential': 'Emissions',
    'Emissions|CO2|Energy|Demand|Industry': 'Emissions',
    'Emissions|CO2|Industrial Processes': 'Emissions',
    'Emissions|CO2|Energy|Demand|Transportation': 'Emissions',
    'Emissions|CO2|Energy and Industrial Processes': 'Emissions',
    'Carbon Sequestration|CCS|Biomass': 'Carbon Sequestration',
    'Carbon Sequestration|Direct Air Capture': 'Carbon Sequestration',}

# %%
def round_to_0_1_percent(value):
    if value == 0:
        return 0
    # Determine the number of significant digits to round to
    magnitude = np.floor(np.log10(abs(value))) - 2
    rounding_factor = 10 ** magnitude
    return np.round(value / rounding_factor) * rounding_factor





df_to_share = df.filter(variable=to_share_vars_topics.keys()).timeseries().reset_index()
ratio_mask = df_to_share['unit'] == '%'
# Apply rounding to the 'value' column for rows where the 'unit' column is '%'
df_to_share.loc[ratio_mask, df_to_share.columns[5:]] = round(df_to_share.loc[ratio_mask, df_to_share.columns[5:]])
# Apply rounding to 0.1 percent for the other variables
df_to_share.loc[:, df_to_share.columns[5:]] = df_to_share.loc[:, df_to_share.columns[5:]].applymap(round_to_0_1_percent)
df_to_share.to_excel('../../../data/TOD/model_results/to_share/IMAGE_and_AIM_to_share_models_SOC.xlsx', index=False)

df_to_share['model'] = df_to_share['variable'].map(to_share_vars_topics).fillna(df_to_share['model'])



df_to_share
# Out:
# C:\Users\maycocks\AppData\Local\Temp\2\ipykernel_5388\3538421022.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_to_share.loc[:, df_to_share.columns[5:]] = df_to_share.loc[:, df_to_share.columns[5:]].applymap(round_to_0_1_percent)
#        model scenario          region                              variable  \
# 0       Land      REF  Africa (UN-R5)                   Agricultural Demand
# 1       Land      REF  Africa (UN-R5)             Agricultural Demand|Crops
# 2       Land      REF  Africa (UN-R5)            Agricultural Demand|Energy
# 3       Land      REF  Africa (UN-R5)      Agricultural Demand|Energy|Crops
# 4       Land      REF  Africa (UN-R5)  Agricultural Demand|Non-Energy|Crops
# ...      ...      ...             ...                                   ...
# 2206  Energy  TECH-TP           World         Primary Energy|Biomass|w/ CCS
# 2207  Energy  TECH-TP           World            Primary Energy|Coal|w/ CCS
# 2208  Energy  TECH-TP           World          Primary Energy|Fossil|w/ CCS
# 2209  Energy  TECH-TP           World             Primary Energy|Gas|w/ CCS
# 2210  Energy  TECH-TP           World             Primary Energy|Oil|w/ CCS
#
#                  unit  2010    2020     2030     2040     2050     2060  \
# 0     million t DM/yr   NaN  561.00  764.000  1020.00  1320.00  1660.00
# 1     million t DM/yr   NaN  542.00  735.000   977.00  1270.00  1590.00
# 2     million t DM/yr   NaN    8.75    7.990     7.71    11.00    21.50
# 3     million t DM/yr   NaN    8.75    8.950     9.64    13.90    25.40
# 4     million t DM/yr   NaN  533.00  726.000   968.00  1250.00  1560.00
# ...               ...   ...     ...      ...      ...      ...      ...
# 2206            EJ/yr   0.0    0.00   13.000    39.00    53.50    55.40
# 2207            EJ/yr   0.0    0.00    2.350    13.30    17.60    14.40
# 2208            EJ/yr   0.0    0.00    9.630    87.20   129.00   125.00
# 2209            EJ/yr   0.0    0.00    6.430    71.10   108.00   108.00
# 2210            EJ/yr   0.0    0.00    0.853     2.82     3.67     2.75
#
#         2070     2080     2090     2100
# 0     2000.0  2330.00  2640.00  2900.00
# 1     1920.0  2230.00  2530.00  2790.00
# 2       29.9    36.20    55.20    68.50
# 3       34.7    42.00    60.90    74.30
# 4     1880.0  2190.00  2470.00  2710.00
# ...      ...      ...      ...      ...
# 2206    61.5    58.90    61.90    64.30
# 2207    12.6    11.00     7.02     5.31
# 2208   111.0   113.00   105.00   100.00
# 2209    94.2    95.80    94.20    91.10
# 2210     4.1     6.17     4.24     4.04
#
# [2211 rows x 15 columns]

# %%
df_to_share.to_excel('../../../data/TOD/model_results/to_share/IMAGE_and_AIM_to_share.xlsx', index=False)
