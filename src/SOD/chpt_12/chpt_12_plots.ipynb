# %%
import pyam
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
ar6_meta_path = '../../../data/SOD/model_results/raw/AR6_Scenarios_Database_metadata_indicators_v1.1.xlsx'
results_path = '../../../data/SOD/model_results/to_share/model_results_to_share_Outlooks.xlsx'
aim_path = '../../../data/SOD/model_results/raw/Consolidated_AIM_GEO7_240621.xlsx'
image_path = '../../../data/SOD/model_results/raw/Consolidated_IMAGE_GEO7_R3_results_12022025_0956.xlsx'

# %%
ar6_meta = pd.read_excel(ar6_meta_path, sheet_name='meta_Ch3vetted_withclimate')
ar6_c1_scenarios = ar6_meta[ar6_meta['Subset_Ch4'] == 'Limit to 1.5C (>50%) no or low OS immediate 2020 action']['Scenario'].unique()
# ar6_c1_scenarios = ar6_meta[ar6_meta['Category_subset'] == 'C1a_NZGHGs']['Scenario'].unique()
ar6_c78_scenarios = ar6_meta[ar6_meta['Subset_Ch4'] == 'Trend from implemented policies']['Scenario'].unique()

# %%
df_emissions_ar6 = pyam.read_iiasa(
    'ar6-public',
    variable=[
            'Primary Energy',
            'Primary Energy|Non-Biomass Renewables',
            'Primary Energy|Biomass',
            'Primary Energy|Biomass|Electricity|w/ CCS',
            'Primary Energy|Biomass|Modern|w/ CCS',
            'Primary Energy|Coal|w/ CCS',
            'Primary Energy|Gas|w/ CCS',
            'Primary Energy|Oil|w/ CCS',
            'Final Energy',
            'Final Energy|Electricity',
            'Emissions|CO2',
            # 'Emissions|CO2|*',
            'Emissions|CO2|Energy',
            'Emissions|CO2|AFOLU',
            'Emissions|Kyoto*',
            'Land Cover|Cropland', 
            'Land Cover|Pasture',
            'Land Cover|Forest',
            'Land Cover|Other Natural Land',
            # 'Land Cover|*',
            'Land Cover|Other Land',
            'Land Cover|Other Arable Land',
            'Carbon Sequestration|CCS',
            'Carbon Sequestration|CCS|Biomass',
            'Carbon Sequestration|CCS|Fossil', 
            ],
    region='World',
    scenario=list(ar6_c1_scenarios),
    
)

df_emissions_ar6 = df_emissions_ar6.filter(year=[2010,  2020,  2030,  2040,  2050])
df_emissions_ar6 = df_emissions_ar6.rename(variable={'Primary Energy|Biomass|Modern|w/ CCS':'Primary Energy|Biomass|w/ CCS',
                                                    #  'Land Cover|Other Land':'Land Cover|Other Natural Land'
                                                     })
df_emissions_ar6.aggregate('Land Cover|Other Natural Land', ['Land Cover|Other Land','Land Cover|Other Arable Land'], append=True)
df_emissions_ar6.variable
# Out:
# [INFO] 11:35:26 - ixmp4.conf.settings: Connecting as user 'stephenmaycock'.
# [INFO] 11:35:26 - pyam.iiasa: You are connected to the IXSE_AR6_PUBLIC scenario explorer hosted by IIASA. If you use this data in any published format, please cite the data as provided in the explorer guidelines: https://data.ece.iiasa.ac.at/ar6/#/about
# [INFO] 11:35:26 - pyam.iiasa: You are connected as user `stephenmaycock`
# ['Carbon Sequestration|CCS',
#  'Carbon Sequestration|CCS|Biomass',
#  'Carbon Sequestration|CCS|Fossil',
#  'Emissions|CO2',
#  'Emissions|CO2|AFOLU',
#  'Emissions|CO2|Energy',
#  'Emissions|Kyoto Gases',
#  'Final Energy',
#  'Final Energy|Electricity',
#  'Land Cover|Cropland',
#  'Land Cover|Forest',
#  'Land Cover|Other Arable Land',
#  'Land Cover|Other Land',
#  'Land Cover|Other Natural Land',
#  'Land Cover|Pasture',
#  'Primary Energy',
#  'Primary Energy|Biomass',
#  'Primary Energy|Biomass|Electricity|w/ CCS',
#  'Primary Energy|Biomass|w/ CCS',
#  'Primary Energy|Coal|w/ CCS',
#  'Primary Energy|Gas|w/ CCS',
#  'Primary Energy|Non-Biomass Renewables',
#  'Primary Energy|Oil|w/ CCS']

# %%
df_emissions_geo = pd.read_excel(results_path)
df_emissions_geo.rename(columns={'topic':'model'}, inplace=True)
df_emissions_geo = pyam.IamDataFrame(df_emissions_geo)
df_emissions_geo = df_emissions_geo.filter(
    variable=[
            'Primary Energy',
            'Primary Energy|Non-Biomass Renewables',
            'Primary Energy|Biomass',
            'Primary Energy|*|w/ CCS',
            'Final Energy',
            'Final Energy|Electricity',
            'Emissions|CO2',
            'Emissions|CO2|Energy',
            'Emissions|CO2|AFOLU',
            'Emissions|Kyoto Gases',
            'Land Cover|Cropland', 
            'Land Cover|Pasture',
            'Land Cover|Forest',
            'Land Cover|Other Natural Land',
            'Carbon Sequestration|CCS',
            'Carbon Sequestration|CCS|Biomass',
            'Carbon Sequestration|CCS|Fossil',
            ],
    region='World',
)
df_emissions_geo = df_emissions_geo.filter(year=[2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050])

df_emissions_geo.variable
# Out:
# ['Carbon Sequestration|CCS',
#  'Carbon Sequestration|CCS|Biomass',
#  'Carbon Sequestration|CCS|Fossil',
#  'Emissions|CO2',
#  'Emissions|CO2|AFOLU',
#  'Emissions|CO2|Energy',
#  'Emissions|Kyoto Gases',
#  'Final Energy',
#  'Final Energy|Electricity',
#  'Primary Energy',
#  'Primary Energy|Biomass',
#  'Primary Energy|Biomass|w/ CCS',
#  'Primary Energy|Coal|w/ CCS',
#  'Primary Energy|Fossil|w/ CCS',
#  'Primary Energy|Gas|w/ CCS',
#  'Primary Energy|Non-Biomass Renewables',
#  'Primary Energy|Oil|w/ CCS',
#  'Land Cover|Cropland',
#  'Land Cover|Pasture']

# %%
df_emissions_geo = df_emissions_geo.data
# Condition to identify rows to be removed
condition_image = (df_emissions_geo['model'] == 'IMAGE 3.3') & (df_emissions_geo['scenario'] == 'REF-v2')

# Remove multiple scenarios for aim
aim_scen_to_remove = ['TECH-TP-v2', 'LIFE-TP-v2']
condition_aim = (df_emissions_geo['model'] == 'AIM/Hub-Global 2.4') & (df_emissions_geo['scenario'].isin(aim_scen_to_remove))

# Remove rows based on the condition
df_emissions_geo = df_emissions_geo[~condition_image]
df_emissions_geo = df_emissions_geo[~condition_aim]

df_emissions_geo = df_emissions_geo.reset_index(drop=True)
df_emissions_geo
# Out:
#          model scenario region                  variable        unit  year  \
# 0    Emissions  LIFE-TP  World  Carbon Sequestration|CCS   Mt CO2/yr  2010
# 1    Emissions  LIFE-TP  World  Carbon Sequestration|CCS   Mt CO2/yr  2020
# 2    Emissions  LIFE-TP  World  Carbon Sequestration|CCS   Mt CO2/yr  2030
# 3    Emissions  LIFE-TP  World  Carbon Sequestration|CCS   Mt CO2/yr  2040
# 4    Emissions  LIFE-TP  World  Carbon Sequestration|CCS   Mt CO2/yr  2050
# ..         ...      ...    ...                       ...         ...   ...
# 269       Land  TECH-TP  World        Land Cover|Pasture  million ha  2010
# 270       Land  TECH-TP  World        Land Cover|Pasture  million ha  2020
# 271       Land  TECH-TP  World        Land Cover|Pasture  million ha  2030
# 272       Land  TECH-TP  World        Land Cover|Pasture  million ha  2040
# 273       Land  TECH-TP  World        Land Cover|Pasture  million ha  2050
#
#       value
# 0       0.0
# 1       0.0
# 2    1340.0
# 3    6310.0
# 4    9150.0
# ..      ...
# 269  3160.0
# 270  3150.0
# 271  3020.0
# 272  2850.0
# 273  2690.0
#
# [274 rows x 7 columns]

# %%
df_geo_data = df_emissions_geo
df_ar6_data = df_emissions_ar6.data
# variables = [
#              'Emissions|Kyoto Gases',
#              ]

variables = df_emissions_geo.variable.unique()

for variable in variables:
    print(variable)
    # Use Seaborn to create the plot with markers and lines
    geo_data = df_geo_data[df_geo_data["variable"] == variable]
    ar6_data = df_ar6_data[df_ar6_data["variable"] == variable]
    # # Define the color palette for scenarios
    scenario_colors = {
        "REF": "black",
        "LIFE-TP": "orange",
        "TECH-TP": "magenta",
        "REF-v2": "black",
        "LIFE-TP-v2": "orange",
        "TECH-TP-v2": "magenta",
    }

    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 6))
    sns.lineplot(
        data=geo_data,
        x="year",
        y="value",
        hue="scenario",
        palette=scenario_colors,
        linewidth=2.5,
        ax=ax
    )
    sns.lineplot(
        data=ar6_data,
        x="year",
        y="value",
        linewidth=0,
        ax=ax,
        # errorbar='sd',
        errorbar=(lambda x: (x.min(), x.max())),
        color='grey'
    )
    ax.legend().set_visible(False)
    # Set labels and title
    plt.xlabel("Year", fontsize=12)
    plt.ylabel(geo_data["unit"].iloc[0], fontsize=12)  # Set the y-axis label to the unit
    ax.set_ylim(min(0,ax.get_ylim()[0]), ax.get_ylim()[1])
    plt.title(variable)  # Set the title to the variable
    plt.xticks([2010, 2020, 2030, 2040, 2050], 
               rotation=45,
               fontsize=12)
    plt.yticks(fontsize=12)

    # Manually add Legend
    handles, labels = ax.get_legend_handles_labels()
    legend_patch = mpatches.Patch(color='grey', alpha=0.3)
    handles = handles + [legend_patch]
    labels = labels + ['C1 IPCC Scenarios']
    fig.legend(handles, labels, title="Legend", bbox_to_anchor=(1.2, 0.9)) 
    plt.grid(True)
    # Adjust layout to ensure legend fits within the saved image
    plt.tight_layout()
    root_variable = variable.split("|")[0].replace(" ", "_")
    variable_name = variable.replace("|", "_").replace(" ", "_").replace("/", "")
    # plt.savefig(f"./plots/chapter_11/{variable_name}.png", bbox_inches="tight")
    plt.savefig(f"../../../plots/SOD/chpt_12/diagnostic/{variable_name}.png", bbox_inches="tight")
    plt.close()
# Out:
# Carbon Sequestration|CCS
# Carbon Sequestration|CCS|Biomass
# Carbon Sequestration|CCS|Fossil
# Emissions|CO2
# Emissions|CO2|AFOLU
# Emissions|CO2|Energy
# Emissions|Kyoto Gases
# Final Energy
# Final Energy|Electricity
# Primary Energy
# Primary Energy|Biomass
# Primary Energy|Biomass|w/ CCS
# Primary Energy|Coal|w/ CCS
# Primary Energy|Fossil|w/ CCS
# Primary Energy|Gas|w/ CCS
# Primary Energy|Non-Biomass Renewables
# Primary Energy|Oil|w/ CCS
# Land Cover|Cropland
# Land Cover|Pasture

# %% [markdown]
# # GHG Sinks and Sources

# %%
df_emissions_sinks_aim = pyam.IamDataFrame(aim_path)
df_emissions_sinks_aim = df_emissions_sinks_aim.filter(variable=[
        'Emissions|CO2|Energy',
        'Emissions|CO2|Energy|Demand|Residential',
        'Emissions|CO2|Energy|Demand|Industry',
        'Emissions|CO2|Industrial Processes',
        'Emissions|CO2|Energy|Demand|Transportation',
        'Emissions|CO2|Energy and Industrial Processes',
        'Carbon Sequestration|CCS|Biomass',
        'Carbon Sequestration|Direct Air Capture',
        'Emissions|CO2|AFOLU',
        'Emissions|CO2|Energy',
        'Emissions|Kyoto Gases',
        'Emissions|CO2'],
        region='World',
        scenario=['REF-v2'],)

df_emissions_sinks_aim.subtract('Emissions|CO2|Energy and Industrial Processes','Emissions|CO2|Energy', 'Emissions|CO2|Industrial Processes', ignore_units='Mt CO2/yr', append=True)
df_emissions_sinks_aim.variable
# Out:
# [INFO] 11:35:51 - pyam.core: Reading file ..\..\..\data\SOD\model_results\raw\Consolidated_AIM_GEO7_240621.xlsx
# ['Emissions|CO2',
#  'Emissions|CO2|AFOLU',
#  'Emissions|CO2|Energy',
#  'Emissions|CO2|Energy and Industrial Processes',
#  'Emissions|CO2|Energy|Demand|Industry',
#  'Emissions|CO2|Energy|Demand|Residential',
#  'Emissions|CO2|Energy|Demand|Transportation',
#  'Emissions|CO2|Industrial Processes',
#  'Emissions|Kyoto Gases']

# %%
df_emissions_sinks_image = pyam.IamDataFrame(image_path)
df_emissions_sinks_image = df_emissions_sinks_image.filter(variable=[
    'Emissions|CO2|Energy|Demand|Residential',
    'Emissions|CO2|Energy|Demand|Industry',
    'Emissions|CO2|Industrial Processes',
    'Emissions|CO2|Energy|Demand|Transportation',
    'Emissions|CO2|Energy and Industrial Processes',
    'Carbon Sequestration|CCS|Biomass',
    'Carbon Sequestration|Direct Air Capture',
    'Emissions|CO2|AFOLU',
    'Emissions|CO2|Energy',
    'Emissions|Kyoto Gases',
    'Emissions|CO2',
    ],
    region='World',
    scenario=['LIFE-TP-v2', 'TECH-TP-v2']
)
df_emissions_sinks_image.variable
# Out:
# [INFO] 11:36:01 - pyam.core: Reading file ..\..\..\data\SOD\model_results\raw\Consolidated_IMAGE_GEO7_R3_results_12022025_0956.xlsx
# ['Carbon Sequestration|CCS|Biomass',
#  'Carbon Sequestration|Direct Air Capture',
#  'Emissions|CO2',
#  'Emissions|CO2|AFOLU',
#  'Emissions|CO2|Energy',
#  'Emissions|CO2|Energy and Industrial Processes',
#  'Emissions|CO2|Energy|Demand|Industry',
#  'Emissions|CO2|Energy|Demand|Residential',
#  'Emissions|CO2|Energy|Demand|Transportation',
#  'Emissions|CO2|Industrial Processes',
#  'Emissions|Kyoto Gases']

# %%
df_carbon_seq_aim = df_emissions_sinks_image.filter(variable='Carbon Sequestration|Direct Air Capture',scenario='LIFE-TP-v2')
df_carbon_seq_aim.rename(model={'IMAGE 3.3':'AIM/Hub-Global 2.4'}, scenario={'LIFE-TP-v2':'REF-v2'}, inplace=True)
df_carbon_seq_aim.multiply('Carbon Sequestration|Direct Air Capture', 0, 'Carbon Sequestration|CCS|Biomass', ignore_units='Mt CO2/yr', append=True)
df_carbon_seq_aim.timeseries()
# Out:
#                                                                                       2005  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2010  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2015  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2020  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2025  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2030  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2035  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2040  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2045  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2050  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2060  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2070  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2080  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2090  \
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0
#
#                                                                                       2100
# model              scenario region variable                                unit
# AIM/Hub-Global 2.4 REF-v2   World  Carbon Sequestration|CCS|Biomass        Mt CO2/yr   0.0
#                                    Carbon Sequestration|Direct Air Capture Mt CO2/yr   0.0

# %%
df_emissions_geo_sinks = pyam.concat([df_emissions_sinks_aim, df_emissions_sinks_image, df_carbon_seq_aim])
df_emissions_geo_sinks.interpolate([2046, 2047, 2048, 2049]).filter(year=[2046, 2047, 2048, 2049]).timeseries()
# Out:
#                                                                                                             2046  \
# model              scenario   region variable                                      unit
# AIM/Hub-Global 2.4 REF-v2     World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr            0.000000
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        58152.512740
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr         2563.296960
#                                      Emissions|CO2|Energy                          Mt CO2/yr        52088.974560
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr        55539.525360
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr        11518.181880
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr         2234.947200
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr        14868.830600
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr         3450.550800
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr  79160.021520
# IMAGE 3.3          LIFE-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         3072.626282
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        -1114.455583
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3420.399890
#                                      Emissions|CO2|Energy                          Mt CO2/yr         1612.621763
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         2305.944250
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          353.615443
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr          332.052945
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         1652.706659
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          693.322053
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   4691.096533
#                    TECH-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         4095.435037
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr          446.374593
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3555.147811
#                                      Emissions|CO2|Energy                          Mt CO2/yr         3165.288572
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         4001.522583
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          414.193369
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr           84.247555
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         2841.022074
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          836.232527
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   7643.707031
#
#                                                                                                             2047  \
# model              scenario   region variable                                      unit
# AIM/Hub-Global 2.4 REF-v2     World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr            0.000000
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        58195.349780
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr         2488.268720
#                                      Emissions|CO2|Energy                          Mt CO2/yr        52180.286220
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr        55657.226620
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr        11601.414660
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr         2192.774600
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr        15093.095300
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr         3476.940400
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr  79335.735940
# IMAGE 3.3          LIFE-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         3073.325637
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        -1684.476458
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3593.471954
#                                      Emissions|CO2|Energy                          Mt CO2/yr         1248.628137
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         1908.995435
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          259.403651
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr          302.986383
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         1479.065728
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          660.367002
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   4041.793164
#                    TECH-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         4196.047335
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr         -253.494029
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3716.246795
#                                      Emissions|CO2|Energy                          Mt CO2/yr         2625.168491
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         3462.753174
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          342.893332
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr           64.141007
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         2619.295081
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          837.583526
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   6883.646484
#
#                                                                                                             2048  \
# model              scenario   region variable                                      unit
# AIM/Hub-Global 2.4 REF-v2     World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr            0.000000
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        58238.186820
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr         2413.240480
#                                      Emissions|CO2|Energy                          Mt CO2/yr        52271.597880
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr        55774.927880
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr        11684.647440
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr         2150.602000
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr        15317.360000
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr         3503.330000
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr  79511.450360
# IMAGE 3.3          LIFE-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         3074.024991
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        -2254.497333
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3766.544017
#                                      Emissions|CO2|Energy                          Mt CO2/yr          884.634510
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         1512.046619
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          165.191859
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr          273.919821
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         1305.424798
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          627.411951
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   3392.489795
#                    TECH-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         4296.659634
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr         -953.362651
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3877.345779
#                                      Emissions|CO2|Energy                          Mt CO2/yr         2085.048409
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         2923.983765
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          271.593294
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr           44.034460
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         2397.568087
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          838.934525
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   6123.585938
#
#                                                                                                             2049
# model              scenario   region variable                                      unit
# AIM/Hub-Global 2.4 REF-v2     World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr            0.000000
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        58281.023860
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr         2338.212240
#                                      Emissions|CO2|Energy                          Mt CO2/yr        52362.909540
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr        55892.629140
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr        11767.880220
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr         2108.429400
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr        15541.624700
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr         3529.719600
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr  79687.164780
# IMAGE 3.3          LIFE-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         3074.724345
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        -2824.518208
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -3939.616080
#                                      Emissions|CO2|Energy                          Mt CO2/yr          520.640884
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         1115.097803
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr           70.980067
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr          244.853259
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         1131.783867
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          594.456900
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   2743.186426
#                    TECH-TP-v2 World  Carbon Sequestration|CCS|Biomass              Mt CO2/yr         4397.271932
#                                      Carbon Sequestration|Direct Air Capture       Mt CO2/yr            0.000000
#                                      Emissions|CO2                                 Mt CO2/yr        -1653.231273
#                                      Emissions|CO2|AFOLU                           Mt CO2/yr        -4038.444762
#                                      Emissions|CO2|Energy                          Mt CO2/yr         1544.928328
#                                      Emissions|CO2|Energy and Industrial Processes Mt CO2/yr         2385.214355
#                                      Emissions|CO2|Energy|Demand|Industry          Mt CO2/yr          200.293257
#                                      Emissions|CO2|Energy|Demand|Residential       Mt CO2/yr           23.927912
#                                      Emissions|CO2|Energy|Demand|Transportation    Mt CO2/yr         2175.841093
#                                      Emissions|CO2|Industrial Processes            Mt CO2/yr          840.285525
#                                      Emissions|Kyoto Gases                         Mt CO2-equiv/yr   5363.525391

# %%
# # GHG sinks
# o	Buildings: Emissions|CO2|Energy|Demand|Residential and Commercial
# o	Industry: Emissions|CO2|Energy|Demand|Industrial Processes + Emissions|CO2|Industrial Processes
# o	Transport: Emissions|CO2|Energy|Demand|Transportation
# o	Energy Supply (pos.): 
# Emissions|CO2|Energy and Industrial Processes - (Emissions|CO2|Energy|Demand|Residential and Commercial + Emissions|CO2|Energy|Demand|Industrial Processes + Emissions|CO2|Industrial Processes + Emissions|CO2|Energy|Demand|Transportation)
# - (Carbon Sequestration|CCS|Biomass + Carbon Sequestration|Direct Air Capture)
# o	Energy Supply (neg.):  Negative of (Carbon Sequestration|CCS|Biomass plus Carbon Sequestration|Direct Air Capture)
# o	AFOLU: Emissions|CO2|AFOLU
# o	Non-CO2: AR6 climate diagnostics|Native-with-Infilled|Emissions|Kyoto Gases AR6-GWP100) - Emissions|CO2


df_emissions_geo_sinks.rename({'scenario':{'REF-v2': 'Current Trends',
                                           'LIFE-TP-v2':"Behaviour-focused", 
                                           'TECH-TP-v2':"Technology-focused"}}, inplace=True)
df_emissions_geo_sinks.aggregate("Buildings", 
                       components=['Emissions|CO2|Energy|Demand|Residential'], 
                    #    ignore_units='Mt CO2/yr',
                        append=True)

df_emissions_geo_sinks.aggregate("Industry", 
                       components=['Emissions|CO2|Energy|Demand|Industry',
                                    'Emissions|CO2|Industrial Processes',],
                        # ignore_units='Mt CO2/yr', 
                        append=True)

df_emissions_geo_sinks.aggregate("Transport", 
                       components=['Emissions|CO2|Energy|Demand|Transportation'],
                    #    ignore_units='Mt CO2/yr', 
                        append=True)

df_emissions_geo_sinks.aggregate("Energy Supply (neg.) temp", 
                       components=['Carbon Sequestration|CCS|Biomass',
                                    'Carbon Sequestration|Direct Air Capture',],
                        # ignore_units='Mt CO2/yr', 
                        append=True)
df_emissions_geo_sinks.multiply('Energy Supply (neg.) temp', -1, 'Energy Supply (neg.)', ignore_units='Mt CO2/yr',
                                append=True)

# Energy Supply (pos.)
df_emissions_geo_sinks.aggregate("Building, Industry & Transport", 
                       components=['Buildings',
                                    'Industry',
                                    'Transport'],
                        # ignore_units='Mt CO2/yr', 
                        append=True)

df_emissions_geo_sinks.subtract('Emissions|CO2|Energy and Industrial Processes', 
                                ["Building, Industry & Transport", 'Energy Supply (neg.)'], 
                                'Energy Supply (pos.)', 
                                ignore_units='Mt CO2/yr',
                                append=True
                                )


df_emissions_geo_sinks.aggregate("Land Use", 
                       components=['Emissions|CO2|AFOLU'],
                    #    ignore_units='Mt CO2/yr', 
                        append=True)

df_emissions_geo_sinks.subtract('Emissions|Kyoto Gases', 'Emissions|CO2', 'Non-CO2', ignore_units='Mt CO2/yr',
                                append=True)

final_var_list = [
    'Buildings',
    'Industry',
    'Transport',
    'Energy Supply (neg.)',
    'Energy Supply (pos.)',
    'Land Use',
    'Non-CO2',
]

df_emissions_geo_sinks = df_emissions_geo_sinks.filter(variable=final_var_list)


df_emissions_geo_sinks.convert_unit('Mt CO2/yr', 'Gt CO2/yr', inplace=True)
df_emissions_geo_sinks.timeseries()
# Out:
#                                                                                   2005  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.762227
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  15.714913
#                                              Industry             Gt CO2/yr   5.602850
#                                              Land Use             Gt CO2/yr   4.573768
#                                              Non-CO2              Gt CO2/yr  12.007237
#                                              Transport            Gt CO2/yr   5.298491
#                    Technology-focused World  Buildings            Gt CO2/yr   1.762227
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  15.714913
#                                              Industry             Gt CO2/yr   5.602850
#                                              Land Use             Gt CO2/yr   4.573768
#                                              Non-CO2              Gt CO2/yr  12.007237
#                                              Transport            Gt CO2/yr   5.298491
#
#                                                                                   2010  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.896557
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  14.997415
#                                              Industry             Gt CO2/yr   8.925889
#                                              Land Use             Gt CO2/yr   5.750792
#                                              Non-CO2              Gt CO2/yr  12.404228
#                                              Transport            Gt CO2/yr   7.150509
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.853317
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  18.211371
#                                              Industry             Gt CO2/yr   6.909749
#                                              Land Use             Gt CO2/yr   5.226955
#                                              Non-CO2              Gt CO2/yr  12.958966
#                                              Transport            Gt CO2/yr   5.663742
#                    Technology-focused World  Buildings            Gt CO2/yr   1.853317
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  18.211438
#                                              Industry             Gt CO2/yr   6.909749
#                                              Land Use             Gt CO2/yr   5.226955
#                                              Non-CO2              Gt CO2/yr  12.959034
#                                              Transport            Gt CO2/yr   5.663896
#
#                                                                                   2015  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.867919
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  16.345738
#                                              Industry             Gt CO2/yr   9.509193
#                                              Land Use             Gt CO2/yr   4.819112
#                                              Non-CO2              Gt CO2/yr  13.206103
#                                              Transport            Gt CO2/yr   7.872974
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.842095
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  19.591692
#                                              Industry             Gt CO2/yr   7.451678
#                                              Land Use             Gt CO2/yr   3.712072
#                                              Non-CO2              Gt CO2/yr  13.770438
#                                              Transport            Gt CO2/yr   6.320644
#                    Technology-focused World  Buildings            Gt CO2/yr   1.842094
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  19.591778
#                                              Industry             Gt CO2/yr   7.451678
#                                              Land Use             Gt CO2/yr   3.712068
#                                              Non-CO2              Gt CO2/yr  13.770534
#                                              Transport            Gt CO2/yr   6.321220
#
#                                                                                   2020  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.001518
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  19.098860
#                                              Industry             Gt CO2/yr   9.943793
#                                              Land Use             Gt CO2/yr   3.866945
#                                              Non-CO2              Gt CO2/yr  14.835833
#                                              Transport            Gt CO2/yr   9.150652
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.970799
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  20.597238
#                                              Industry             Gt CO2/yr   8.075029
#                                              Land Use             Gt CO2/yr   3.495390
#                                              Non-CO2              Gt CO2/yr  14.899479
#                                              Transport            Gt CO2/yr   6.167645
#                    Technology-focused World  Buildings            Gt CO2/yr   1.972178
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  20.571707
#                                              Industry             Gt CO2/yr   7.852050
#                                              Land Use             Gt CO2/yr   3.497083
#                                              Non-CO2              Gt CO2/yr  14.854759
#                                              Transport            Gt CO2/yr   6.165636
#
#                                                                                   2025  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.368030
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  23.237171
#                                              Industry             Gt CO2/yr  11.217988
#                                              Land Use             Gt CO2/yr   3.896365
#                                              Non-CO2              Gt CO2/yr  17.692756
#                                              Transport            Gt CO2/yr  10.550082
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.759591
#                                              Energy Supply (neg.) Gt CO2/yr  -0.108725
#                                              Energy Supply (pos.) Gt CO2/yr  17.135179
#                                              Industry             Gt CO2/yr   6.931776
#                                              Land Use             Gt CO2/yr   3.993750
#                                              Non-CO2              Gt CO2/yr  13.071184
#                                              Transport            Gt CO2/yr   6.160858
#                    Technology-focused World  Buildings            Gt CO2/yr   1.824296
#                                              Energy Supply (neg.) Gt CO2/yr  -0.046904
#                                              Energy Supply (pos.) Gt CO2/yr  17.977331
#                                              Industry             Gt CO2/yr   6.320718
#                                              Land Use             Gt CO2/yr   4.007605
#                                              Non-CO2              Gt CO2/yr  13.289890
#                                              Transport            Gt CO2/yr   6.806239
#
#                                                                                   2030  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.688139
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  23.494329
#                                              Industry             Gt CO2/yr  12.210248
#                                              Land Use             Gt CO2/yr   3.871215
#                                              Non-CO2              Gt CO2/yr  18.043248
#                                              Transport            Gt CO2/yr  11.687071
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   1.404592
#                                              Energy Supply (neg.) Gt CO2/yr  -0.804154
#                                              Energy Supply (pos.) Gt CO2/yr   8.767304
#                                              Industry             Gt CO2/yr   5.135229
#                                              Land Use             Gt CO2/yr   0.788897
#                                              Non-CO2              Gt CO2/yr  10.353944
#                                              Transport            Gt CO2/yr   5.067979
#                    Technology-focused World  Buildings            Gt CO2/yr   1.533537
#                                              Energy Supply (neg.) Gt CO2/yr  -0.914776
#                                              Energy Supply (pos.) Gt CO2/yr  10.286523
#                                              Industry             Gt CO2/yr   5.173595
#                                              Land Use             Gt CO2/yr   0.940322
#                                              Non-CO2              Gt CO2/yr  10.926815
#                                              Transport            Gt CO2/yr   5.926481
#
#                                                                                   2035  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.625329
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  24.560974
#                                              Industry             Gt CO2/yr  13.194399
#                                              Land Use             Gt CO2/yr   3.444597
#                                              Non-CO2              Gt CO2/yr  19.334340
#                                              Transport            Gt CO2/yr  12.580509
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.903013
#                                              Energy Supply (neg.) Gt CO2/yr  -2.088952
#                                              Energy Supply (pos.) Gt CO2/yr   4.423120
#                                              Industry             Gt CO2/yr   3.553571
#                                              Land Use             Gt CO2/yr  -0.508536
#                                              Non-CO2              Gt CO2/yr   8.282435
#                                              Transport            Gt CO2/yr   4.041308
#                    Technology-focused World  Buildings            Gt CO2/yr   0.908524
#                                              Energy Supply (neg.) Gt CO2/yr  -2.100797
#                                              Energy Supply (pos.) Gt CO2/yr   5.803955
#                                              Industry             Gt CO2/yr   3.534078
#                                              Land Use             Gt CO2/yr  -1.290242
#                                              Non-CO2              Gt CO2/yr   9.131627
#                                              Transport            Gt CO2/yr   5.075440
#
#                                                                                   2040  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.344874
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  24.228476
#                                              Industry             Gt CO2/yr  14.111823
#                                              Land Use             Gt CO2/yr   3.012081
#                                              Non-CO2              Gt CO2/yr  20.044325
#                                              Transport            Gt CO2/yr  13.687061
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.600350
#                                              Energy Supply (neg.) Gt CO2/yr  -2.469312
#                                              Energy Supply (pos.) Gt CO2/yr   3.017930
#                                              Industry             Gt CO2/yr   2.261935
#                                              Land Use             Gt CO2/yr  -2.259036
#                                              Non-CO2              Gt CO2/yr   6.907623
#                                              Transport            Gt CO2/yr   2.916419
#                    Technology-focused World  Buildings            Gt CO2/yr   0.393695
#                                              Energy Supply (neg.) Gt CO2/yr  -3.132395
#                                              Energy Supply (pos.) Gt CO2/yr   4.680392
#                                              Industry             Gt CO2/yr   2.136238
#                                              Land Use             Gt CO2/yr  -2.698583
#                                              Non-CO2              Gt CO2/yr   8.042056
#                                              Transport            Gt CO2/yr   4.021516
#
#                                                                                   2045  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.277120
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  23.641028
#                                              Industry             Gt CO2/yr  14.859110
#                                              Land Use             Gt CO2/yr   2.638325
#                                              Non-CO2              Gt CO2/yr  20.874631
#                                              Transport            Gt CO2/yr  14.644566
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.361120
#                                              Energy Supply (neg.) Gt CO2/yr  -3.071927
#                                              Energy Supply (pos.) Gt CO2/yr   2.413249
#                                              Industry             Gt CO2/yr   1.174104
#                                              Land Use             Gt CO2/yr  -3.247328
#                                              Non-CO2              Gt CO2/yr   5.884835
#                                              Transport            Gt CO2/yr   1.826348
#                    Technology-focused World  Buildings            Gt CO2/yr   0.104354
#                                              Energy Supply (neg.) Gt CO2/yr  -3.994823
#                                              Energy Supply (pos.) Gt CO2/yr   4.047637
#                                              Industry             Gt CO2/yr   1.320375
#                                              Land Use             Gt CO2/yr  -3.394049
#                                              Non-CO2              Gt CO2/yr   7.257524
#                                              Transport            Gt CO2/yr   3.062749
#
#                                                                                   2050  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.066257
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  22.770962
#                                              Industry             Gt CO2/yr  15.407222
#                                              Land Use             Gt CO2/yr   2.263184
#                                              Non-CO2              Gt CO2/yr  21.539018
#                                              Transport            Gt CO2/yr  15.765889
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.215787
#                                              Energy Supply (neg.) Gt CO2/yr  -3.075424
#                                              Energy Supply (pos.) Gt CO2/yr   2.081373
#                                              Industry             Gt CO2/yr   0.538270
#                                              Land Use             Gt CO2/yr  -4.112688
#                                              Non-CO2              Gt CO2/yr   5.488422
#                                              Transport            Gt CO2/yr   0.958143
#                    Technology-focused World  Buildings            Gt CO2/yr   0.003821
#                                              Energy Supply (neg.) Gt CO2/yr  -4.497884
#                                              Energy Supply (pos.) Gt CO2/yr   3.415764
#                                              Industry             Gt CO2/yr   0.970630
#                                              Land Use             Gt CO2/yr  -4.199544
#                                              Non-CO2              Gt CO2/yr   6.956565
#                                              Transport            Gt CO2/yr   1.954114
#
#                                                                                   2055  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   2.020568
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr  23.206475
#                                              Industry             Gt CO2/yr  15.989696
#                                              Land Use             Gt CO2/yr   2.245320
#                                              Non-CO2              Gt CO2/yr  22.613369
#                                              Transport            Gt CO2/yr  17.408048
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#                    Technology-focused World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#
#                                                                                   2060  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.969531
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  22.671061
#                                              Industry             Gt CO2/yr  16.662437
#                                              Land Use             Gt CO2/yr   2.224773
#                                              Non-CO2              Gt CO2/yr  23.157371
#                                              Transport            Gt CO2/yr  18.854788
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.083510
#                                              Energy Supply (neg.) Gt CO2/yr  -2.844202
#                                              Energy Supply (pos.) Gt CO2/yr   1.366830
#                                              Industry             Gt CO2/yr   0.322107
#                                              Land Use             Gt CO2/yr  -2.804102
#                                              Non-CO2              Gt CO2/yr   5.239297
#                                              Transport            Gt CO2/yr   0.300355
#                    Technology-focused World  Buildings            Gt CO2/yr   0.000358
#                                              Energy Supply (neg.) Gt CO2/yr  -4.694149
#                                              Energy Supply (pos.) Gt CO2/yr   2.733738
#                                              Industry             Gt CO2/yr   0.764365
#                                              Land Use             Gt CO2/yr  -4.028113
#                                              Non-CO2              Gt CO2/yr   6.809089
#                                              Transport            Gt CO2/yr   0.832032
#
#                                                                                   2065  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.668803
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr  22.835260
#                                              Industry             Gt CO2/yr  17.161794
#                                              Land Use             Gt CO2/yr   1.963296
#                                              Non-CO2              Gt CO2/yr  23.872184
#                                              Transport            Gt CO2/yr  20.266433
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#                    Technology-focused World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#
#                                                                                   2070  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.508418
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  22.825887
#                                              Industry             Gt CO2/yr  17.648683
#                                              Land Use             Gt CO2/yr   1.701051
#                                              Non-CO2              Gt CO2/yr  24.825634
#                                              Transport            Gt CO2/yr  21.776798
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.045424
#                                              Energy Supply (neg.) Gt CO2/yr  -2.838422
#                                              Energy Supply (pos.) Gt CO2/yr   1.132780
#                                              Industry             Gt CO2/yr   0.300279
#                                              Land Use             Gt CO2/yr  -1.603005
#                                              Non-CO2              Gt CO2/yr   5.126225
#                                              Transport            Gt CO2/yr   0.223832
#                    Technology-focused World  Buildings            Gt CO2/yr   0.000234
#                                              Energy Supply (neg.) Gt CO2/yr  -5.199493
#                                              Energy Supply (pos.) Gt CO2/yr   2.355124
#                                              Industry             Gt CO2/yr   0.597238
#                                              Land Use             Gt CO2/yr  -3.472112
#                                              Non-CO2              Gt CO2/yr   6.695569
#                                              Transport            Gt CO2/yr   0.522679
#
#                                                                                   2075  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.201537
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr  21.689564
#                                              Industry             Gt CO2/yr  17.612061
#                                              Land Use             Gt CO2/yr   1.533433
#                                              Non-CO2              Gt CO2/yr  25.294551
#                                              Transport            Gt CO2/yr  23.178786
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#                    Technology-focused World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#
#                                                                                   2080  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.332495
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  20.227248
#                                              Industry             Gt CO2/yr  17.415785
#                                              Land Use             Gt CO2/yr   1.366346
#                                              Non-CO2              Gt CO2/yr  25.696128
#                                              Transport            Gt CO2/yr  24.560037
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.032877
#                                              Energy Supply (neg.) Gt CO2/yr  -2.595711
#                                              Energy Supply (pos.) Gt CO2/yr   1.151861
#                                              Industry             Gt CO2/yr   0.090192
#                                              Land Use             Gt CO2/yr  -1.335686
#                                              Non-CO2              Gt CO2/yr   4.903470
#                                              Transport            Gt CO2/yr   0.213429
#                    Technology-focused World  Buildings            Gt CO2/yr   0.000182
#                                              Energy Supply (neg.) Gt CO2/yr  -4.999883
#                                              Energy Supply (pos.) Gt CO2/yr   1.948580
#                                              Industry             Gt CO2/yr   0.512245
#                                              Land Use             Gt CO2/yr  -3.026803
#                                              Non-CO2              Gt CO2/yr   6.237251
#                                              Transport            Gt CO2/yr   0.336571
#
#                                                                                   2085  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.357326
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr  18.424421
#                                              Industry             Gt CO2/yr  16.990895
#                                              Land Use             Gt CO2/yr   1.319770
#                                              Non-CO2              Gt CO2/yr  26.372226
#                                              Transport            Gt CO2/yr  25.515589
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#                    Technology-focused World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#
#                                                                                   2090  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.405677
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  17.619821
#                                              Industry             Gt CO2/yr  16.840794
#                                              Land Use             Gt CO2/yr   1.274177
#                                              Non-CO2              Gt CO2/yr  26.539423
#                                              Transport            Gt CO2/yr  26.382875
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.029204
#                                              Energy Supply (neg.) Gt CO2/yr  -2.794223
#                                              Energy Supply (pos.) Gt CO2/yr   1.027181
#                                              Industry             Gt CO2/yr   0.054164
#                                              Land Use             Gt CO2/yr  -1.253313
#                                              Non-CO2              Gt CO2/yr   4.622262
#                                              Transport            Gt CO2/yr   0.199225
#                    Technology-focused World  Buildings            Gt CO2/yr   0.000109
#                                              Energy Supply (neg.) Gt CO2/yr  -5.309151
#                                              Energy Supply (pos.) Gt CO2/yr   1.754204
#                                              Industry             Gt CO2/yr   0.385818
#                                              Land Use             Gt CO2/yr  -2.794149
#                                              Non-CO2              Gt CO2/yr   5.789950
#                                              Transport            Gt CO2/yr   0.219054
#
#                                                                                   2095  \
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.480285
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr  15.174375
#                                              Industry             Gt CO2/yr  16.403765
#                                              Land Use             Gt CO2/yr   1.124074
#                                              Non-CO2              Gt CO2/yr  26.736855
#                                              Transport            Gt CO2/yr  27.750038
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#                    Technology-focused World  Buildings            Gt CO2/yr        NaN
#                                              Energy Supply (neg.) Gt CO2/yr        NaN
#                                              Energy Supply (pos.) Gt CO2/yr        NaN
#                                              Industry             Gt CO2/yr        NaN
#                                              Land Use             Gt CO2/yr        NaN
#                                              Non-CO2              Gt CO2/yr        NaN
#                                              Transport            Gt CO2/yr        NaN
#
#                                                                                   2100
# model              scenario           region variable             unit
# AIM/Hub-Global 2.4 Current Trends     World  Buildings            Gt CO2/yr   1.545095
#                                              Energy Supply (neg.) Gt CO2/yr  -0.000000
#                                              Energy Supply (pos.) Gt CO2/yr  14.908443
#                                              Industry             Gt CO2/yr  16.019538
#                                              Land Use             Gt CO2/yr   0.975706
#                                              Non-CO2              Gt CO2/yr  26.968157
#                                              Transport            Gt CO2/yr  28.870208
# IMAGE 3.3          Behaviour-focused  World  Buildings            Gt CO2/yr   0.024567
#                                              Energy Supply (neg.) Gt CO2/yr  -2.695169
#                                              Energy Supply (pos.) Gt CO2/yr   0.846121
#                                              Industry             Gt CO2/yr   0.095371
#                                              Land Use             Gt CO2/yr  -0.980395
#                                              Non-CO2              Gt CO2/yr   4.373030
#                                              Transport            Gt CO2/yr   0.184464
#                    Technology-focused World  Buildings            Gt CO2/yr   0.000086
#                                              Energy Supply (neg.) Gt CO2/yr  -5.697129
#                                              Energy Supply (pos.) Gt CO2/yr   2.017768
#                                              Industry             Gt CO2/yr  -0.136471
#                                              Land Use             Gt CO2/yr  -2.679571
#                                              Non-CO2              Gt CO2/yr   5.492303
#                                              Transport            Gt CO2/yr   0.152493

# %%
def fill_series(x, time):
    """Returns the timeseries value at a point in time by linear interpolation

    Parameters
    ----------
    x : pandas.Series
        a timeseries to be interpolated
    time : int or pandas.datetime
        year or datetime to interpolate
    """
    x = x.dropna()
    if time in x.index and not np.isnan(x[time]):
        return x[time]
    else:
        prev = [i for i in x.columns if i < time]
        nxt = [i for i in x.columns if i > time]
        if prev and nxt:
            p = max(prev)
            n = min(nxt)
            return ((n - time) * x[p] + (time - p) * x[n]) / (n - p)
        else:
            return np.nan
        
# Calculate the netzero values
# Netzero time manually checked
# Create dummy year to add both netzero years in same dataframe
life_df = df_emissions_geo_sinks.filter(scenario="Behaviour-focused").timeseries()
life_netzero_year = 2048
netzero_life_df = pd.DataFrame()
netzero_life_df[9999] = fill_series(life_df, life_netzero_year)

tech_df = df_emissions_geo_sinks.filter(scenario="Technology-focused").timeseries()
tech_netzero_year = 2049
netzero_tech_df = pd.DataFrame()
netzero_tech_df[9999] = fill_series(tech_df, tech_netzero_year)
netzero_tech_df
# Out:
#                                                                         9999
# model     scenario           region variable             unit
# IMAGE 3.3 Technology-focused World  Buildings            Gt CO2/yr  0.023928
#                                     Energy Supply (neg.) Gt CO2/yr -4.397272
#                                     Energy Supply (pos.) Gt CO2/yr  3.542139
#                                     Industry             Gt CO2/yr  1.040579
#                                     Land Use             Gt CO2/yr -4.038445
#                                     Non-CO2              Gt CO2/yr  7.016757
#                                     Transport            Gt CO2/yr  2.175841

# %%
print('life',netzero_life_df.sum() - netzero_life_df.iloc[-2])
print('tech',netzero_tech_df.sum() - netzero_tech_df.iloc[-2])
# Out:
# life 9999   -2.254497
# dtype: float64
# tech 9999   -1.65323
# dtype: float64

# %%
pyam_netzero = pyam.concat([netzero_life_df, netzero_tech_df]).filter(year=[9999])
df_emissions_geo_sinks_2020 = df_emissions_geo_sinks.filter(scenario='Current Trends', year=[2020, 2050])
pyam_netzero.timeseries()
# Out:
#                                                                         9999
# model     scenario           region variable             unit
# IMAGE 3.3 Behaviour-focused  World  Buildings            Gt CO2/yr  0.273920
#                                     Energy Supply (neg.) Gt CO2/yr -3.074025
#                                     Energy Supply (pos.) Gt CO2/yr  2.214123
#                                     Industry             Gt CO2/yr  0.792604
#                                     Land Use             Gt CO2/yr -3.766544
#                                     Non-CO2              Gt CO2/yr  5.646987
#                                     Transport            Gt CO2/yr  1.305425
#           Technology-focused World  Buildings            Gt CO2/yr  0.023928
#                                     Energy Supply (neg.) Gt CO2/yr -4.397272
#                                     Energy Supply (pos.) Gt CO2/yr  3.542139
#                                     Industry             Gt CO2/yr  1.040579
#                                     Land Use             Gt CO2/yr -4.038445
#                                     Non-CO2              Gt CO2/yr  7.016757
#                                     Transport            Gt CO2/yr  2.175841

# %%
import matplotlib.colors
cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ['orange', 'magenta', 'brown', 'black', 'blue', 'grey'])

# Set the number of columns for subplots
num_cols = 2
# Calculate the number of rows needed
num_rows = 1

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(6, 10), sharey=True) # , gridspec_kw={'width_ratios': [1, 3]}

df_emissions_geo_sinks_2020.plot.bar(
   x='year', 
   bars="variable", 
   stacked=True, 
   title="", 
   cmap="tab20", 
   ax=axes[0],
   alpha=0.9
)

pyam_netzero.plot.bar(
   x='scenario', 
   bars="variable", 
   stacked=True, 
   title="At timing of net zero CO2", 
   cmap="tab20",
   ax=axes[1],
   alpha=0.9
)

axes[0].set(xlabel=None)
axes[0].set(xticklabels=[2020, '2050 under Current Trends scenario'])
axes[0].set(ylabel='Gt CO2eq/yr')

axes[0].legend().set_visible(False)

axes[1].set(xlabel=None)
axes[1].set(ylabel=None)
# axes[1].set(yticklabels=[])
axes[1].legend(bbox_to_anchor=(1.4, 0.55))
fig.suptitle('GHG Emissions By Sector')
plt.legend(loc=1)
plt.tight_layout()
# plt.savefig(f"../plots/chapter_12/GHG_shares_per_sector_net_zero.png", bbox_inches="tight")
plt.savefig(f"../../../plots/SOD/chpt_12/report/GHG_shares_per_sector_net_zero.png", bbox_inches="tight")
plt.savefig(f"../../../plots/SOD/chpt_12/report/GHG_shares_per_sector_net_zero.svg", bbox_inches="tight")
# plt.close()
