# %%
import pandas as pd
import pyam
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
gtem_path = '../../../data/SOD/model_results/raw/Consolidated_GTEM_GEO7_R2_results_20240716.xlsx'

# %%
def round_to_0_1_percent(value):
    if value == 0:
        return 0
    # Determine the number of significant digits to round to
    magnitude = np.floor(np.log10(abs(value))) - 2
    rounding_factor = 10 ** magnitude
    return np.round(value / rounding_factor) * rounding_factor

# %%
df_unclean = pd.read_excel(gtem_path)
gtem_vars_to_share = {
    'Forestry Production|Roundwood|Industrial Roundwood':'Forestry Production|Roundwood|Industrial Roundwood',
    'Material Extraction|Wild catch':'Material Extraction|Wild Catch', 
    'Material Extraction|Copper':'Material Extraction|Copper',
    'Material Extraction|Iron ore':'Material Extraction|Iron Ore', 
    'Material Extraction|Aluminium':'Material Extraction|Aluminium',
    'Material Extraction|Other metals and concentrates':'Material Extraction|Other Metals and Concentrates',
    'Material Extraction|Sand gravel and rock for construction':'Material Extraction|Sand Gravel and Rock for Construction',
    'Material Extraction|Industrial sand and gravel':'Material Extraction|Industrial Sand and Gravel',
    'Material Extraction|Other non-metallic minerals':'Material Extraction|Other Non-Metallic Minerals',
    'Material Demand|Wild catch':'Material Demand|Wild Catch', 
    'Material Demand|Copper':'Material Demand|Copper',
    'Material Demand|Iron ore':'Material Demand|Iron Ore', 
    'Material Demand|Aluminium':'Material Demand|Aluminium',
    'Material Demand|Other metals and concentrates':'Material Demand|Other Metals and Concentrates',
    'Material Demand|Sand gravel and rock for construction':'Material Demand|Sand Gravel and Rock for Construction',
    'Material Demand|Industrial sand and gravel':'Material Demand|Industrial Sand and Gravel',
    'Material Demand|Other non-metallic minerals':'Material Demand|Other Non-Metallic Minerals',
    'Material Demand|Total':'Material Demand|Total',
    'Recycling rate|Copper':'Recycling Rate|Copper',
    'Recycling rate|Iron ore':'Recycling Rate|Iron Ore', 
    'Recycling rate|Aluminium':'Recycling Rate|Aluminium',
    'Recycling rate|Othe metals':'Recycling Rate|Other Metals',
    'Recycling rate|Industrial Roundwood':'Recycling Rate|Industrial Roundwood',
    'Recycling rate|Sand gravel and rock for construction':'Recycling Rate|Sand Gravel and Rock for Construction',
    'Recycling rate|Industrial sand and gavel':'Recycling Rate|Industrial Sand and Gravel',
    'Recycling rate|Other non-metallic minerals':'Recycling Rate|Other Non-Metallic Minerals',
}


df_unclean = df_unclean[df_unclean['Variable'].isin(gtem_vars_to_share.keys())]
df_unclean['Variable'] = df_unclean['Variable'].replace(gtem_vars_to_share)
df_unclean.loc[df_unclean['Variable'] =='Forestry Production|Roundwood|Industrial Roundwood', ['Unit']] = 'million m3/yr'

ratio_mask = df_unclean['Unit'] == '%'
# Apply rounding to the 'value' column for rows where the 'unit' column is '%'
df_unclean.loc[ratio_mask, df_unclean.columns[5:]] = round(df_unclean.loc[ratio_mask, df_unclean.columns[5:]])

# Conversion factor m3 wood to kg roundwood (kg/m3)
# Number taken from FAO yearbook of forest products 1981-1992
# Average of fuelwood and pulpwood  and same as coniferous sawlogs
cvm3kg = 700
roundwood_mask = df_unclean['Variable'] == 'Forestry Production|Roundwood|Industrial Roundwood'
# Apply rounding to the 'value' column for rows where the 'unit' column is '%'
df_unclean.loc[roundwood_mask, df_unclean.columns[5:]] = df_unclean.loc[roundwood_mask, df_unclean.columns[5:]] * 1000 / cvm3kg

df_unclean.loc[:, df_unclean.columns[5:]] = df_unclean.loc[:, df_unclean.columns[5:]].applymap(round_to_0_1_percent)

df_unclean
# Out:
# C:\Users\maycocks\AppData\Local\Temp\2\ipykernel_8848\613480736.py:48: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_unclean.loc[:, df_unclean.columns[5:]] = df_unclean.loc[:, df_unclean.columns[5:]].applymap(round_to_0_1_percent)
#                    Model    Scenario Region  \
# 490   GTEM-Resource_2023      REF-v2    ARG
# 491   GTEM-Resource_2023      REF-v2    AUS
# 492   GTEM-Resource_2023      REF-v2    BGD
# 493   GTEM-Resource_2023      REF-v2    BRA
# 494   GTEM-Resource_2023      REF-v2    CAN
# ...                  ...         ...    ...
# 4440  GTEM-Resource_2023  LIFE-TP-v2    TUR
# 4441  GTEM-Resource_2023  LIFE-TP-v2    GBR
# 4442  GTEM-Resource_2023  LIFE-TP-v2    USA
# 4443  GTEM-Resource_2023  LIFE-TP-v2    VNM
# 4444  GTEM-Resource_2023  LIFE-TP-v2  World
#
#                                                Variable           Unit  \
# 490   Forestry Production|Roundwood|Industrial Round...  million m3/yr
# 491   Forestry Production|Roundwood|Industrial Round...  million m3/yr
# 492   Forestry Production|Roundwood|Industrial Round...  million m3/yr
# 493   Forestry Production|Roundwood|Industrial Round...  million m3/yr
# 494   Forestry Production|Roundwood|Industrial Round...  million m3/yr
# ...                                                 ...            ...
# 4440         Recycling Rate|Other Non-Metallic Minerals              %
# 4441         Recycling Rate|Other Non-Metallic Minerals              %
# 4442         Recycling Rate|Other Non-Metallic Minerals              %
# 4443         Recycling Rate|Other Non-Metallic Minerals              %
# 4444         Recycling Rate|Other Non-Metallic Minerals              %
#
#         2015     2016     2017     2018     2019  ...     2051     2052  \
# 490     9.88   10.700   11.500   11.500   11.800  ...   19.900   20.100
# 491    23.10   25.500   28.200   28.100   28.400  ...   37.900   38.100
# 492     0.40    0.401    0.387    0.401    0.387  ...    0.287    0.279
# 493   123.00  131.000  136.000  144.000  147.000  ...  206.000  207.000
# 494   119.00  122.000  123.000  123.000  121.000  ...  142.000  142.000
# ...      ...      ...      ...      ...      ...  ...      ...      ...
# 4440   10.00   10.000   10.000   10.000   10.000  ...   15.000   15.000
# 4441   10.00   10.000   10.000   10.000   10.000  ...   15.000   15.000
# 4442   10.00   10.000   10.000   10.000   10.000  ...   15.000   15.000
# 4443   10.00   10.000   10.000   10.000   10.000  ...   15.000   15.000
# 4444   10.00   10.000   10.000   10.000   10.000  ...   15.000   15.000
#
#          2053     2054     2055     2056     2057     2058     2059    2060
# 490    20.300   20.500   20.700   20.900   21.100   21.300   21.500   21.70
# 491    38.400   38.600   38.800   39.000   39.200   39.400   39.700   39.90
# 492     0.273    0.266    0.259    0.253    0.247    0.241    0.235    0.23
# 493   208.000  209.000  210.000  211.000  212.000  213.000  214.000  215.00
# 494   142.000  142.000  142.000  142.000  142.000  142.000  142.000  142.00
# ...       ...      ...      ...      ...      ...      ...      ...     ...
# 4440   15.000   15.000   15.000   15.000   15.000   15.000   15.000   15.00
# 4441   15.000   15.000   15.000   15.000   15.000   15.000   15.000   15.00
# 4442   15.000   15.000   15.000   15.000   15.000   15.000   15.000   15.00
# 4443   15.000   15.000   15.000   15.000   15.000   15.000   15.000   15.00
# 4444   15.000   15.000   15.000   15.000   15.000   15.000   15.000   15.00
#
# [2730 rows x 51 columns]

# %%
df_unclean = pyam.IamDataFrame(df_unclean)
df_copy = df_unclean.timeseries()
# Remove the model level from index
# df_copy = df_copy.reset_index(level='model', drop=True)
df_copy.columns = df_copy.columns.astype(str)

hist_filtered = df_unclean.filter(scenario='REF-v2', year=[2020]).timeseries()
# hist_filtered = hist_filtered.copy().reset_index(level='model', drop=True)
hist_filtered.columns = hist_filtered.columns.astype(str)

def change_first_level_index_value(df, old_value, new_value):
    new_index = df.index.to_frame()  # Convert index to DataFrame
    new_index.loc[new_index['scenario'] == old_value, 'scenario'] = new_value  # Change the values
    new_df = df.copy()
    new_df.index = pd.MultiIndex.from_frame(new_index)  # Convert back to MultiIndex
    return new_df

# Change 'A' to 'C' in the first level of the MultiIndex
life_hist = change_first_level_index_value(hist_filtered, 'REF-v2', 'LIFE-TP-v2')
tech_hist = change_first_level_index_value(hist_filtered, 'REF-v2', 'TECH-TP-v2')

hist_conc = pd.concat([hist_filtered, life_hist, tech_hist])
df_copy['2020'] = hist_conc['2020']
df_copy
# Out:
#                                                                                                              2015  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       9.880
#                                      Material Demand|Aluminium                          million tons/year   0.184
#                                      Material Demand|Copper                             million tons/year   2.770
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.586
#                                      Material Demand|Iron Ore                           million tons/year   0.297
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2016  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      10.700
#                                      Material Demand|Aluminium                          million tons/year   0.182
#                                      Material Demand|Copper                             million tons/year   2.660
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.587
#                                      Material Demand|Iron Ore                           million tons/year   0.276
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2017  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.500
#                                      Material Demand|Aluminium                          million tons/year   0.169
#                                      Material Demand|Copper                             million tons/year   2.620
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.623
#                                      Material Demand|Iron Ore                           million tons/year   0.284
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2018  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.500
#                                      Material Demand|Aluminium                          million tons/year   0.138
#                                      Material Demand|Copper                             million tons/year   2.550
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.617
#                                      Material Demand|Iron Ore                           million tons/year   0.277
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2019  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.700
#                                      Material Demand|Aluminium                          million tons/year   0.136
#                                      Material Demand|Copper                             million tons/year   2.480
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.617
#                                      Material Demand|Iron Ore                           million tons/year   0.278
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2020  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      10.600
#                                      Material Demand|Aluminium                          million tons/year   0.129
#                                      Material Demand|Copper                             million tons/year   2.360
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.571
#                                      Material Demand|Iron Ore                           million tons/year   0.268
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  70.000
#                                      Recycling Rate|Iron Ore                            %                  78.000
#                                      Recycling Rate|Other Metals                        %                  29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  70.000
#
#                                                                                                              2021  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.400
#                                      Material Demand|Aluminium                          million tons/year   0.125
#                                      Material Demand|Copper                             million tons/year   2.290
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.648
#                                      Material Demand|Iron Ore                           million tons/year   0.280
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  71.000
#                                      Recycling Rate|Iron Ore                            %                  79.000
#                                      Recycling Rate|Other Metals                        %                  30.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  71.000
#
#                                                                                                              2022  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.600
#                                      Material Demand|Aluminium                          million tons/year   0.126
#                                      Material Demand|Copper                             million tons/year   2.290
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.685
#                                      Material Demand|Iron Ore                           million tons/year   0.294
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  71.000
#                                      Recycling Rate|Iron Ore                            %                  79.000
#                                      Recycling Rate|Other Metals                        %                  30.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  11.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  71.000
#
#                                                                                                              2023  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.800
#                                      Material Demand|Aluminium                          million tons/year   0.127
#                                      Material Demand|Copper                             million tons/year   2.310
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.716
#                                      Material Demand|Iron Ore                           million tons/year   0.306
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  72.000
#                                      Recycling Rate|Iron Ore                            %                  80.000
#                                      Recycling Rate|Other Metals                        %                  31.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  11.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  72.000
#
#                                                                                                              2024  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      11.900
#                                      Material Demand|Aluminium                          million tons/year   0.129
#                                      Material Demand|Copper                             million tons/year   2.340
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.745
#                                      Material Demand|Iron Ore                           million tons/year   0.319
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  72.000
#                                      Recycling Rate|Iron Ore                            %                  80.000
#                                      Recycling Rate|Other Metals                        %                  31.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  12.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  72.000
#
#                                                                                                            ...  \
# model              scenario   region variable                                           unit               ...
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr      ...
#                                      Material Demand|Aluminium                          million tons/year  ...
#                                      Material Demand|Copper                             million tons/year  ...
#                                      Material Demand|Industrial Sand and Gravel         million tons/year  ...
#                                      Material Demand|Iron Ore                           million tons/year  ...
# ...                                                                                                        ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  ...
#                                      Recycling Rate|Iron Ore                            %                  ...
#                                      Recycling Rate|Other Metals                        %                  ...
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  ...
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  ...
#
#                                                                                                              2051  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.770
#                                      Material Demand|Aluminium                          million tons/year   0.110
#                                      Material Demand|Copper                             million tons/year   1.960
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.677
#                                      Material Demand|Iron Ore                           million tons/year   0.258
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2052  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.650
#                                      Material Demand|Aluminium                          million tons/year   0.113
#                                      Material Demand|Copper                             million tons/year   2.000
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.687
#                                      Material Demand|Iron Ore                           million tons/year   0.266
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2053  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.540
#                                      Material Demand|Aluminium                          million tons/year   0.115
#                                      Material Demand|Copper                             million tons/year   2.030
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.698
#                                      Material Demand|Iron Ore                           million tons/year   0.274
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2054  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.420
#                                      Material Demand|Aluminium                          million tons/year   0.117
#                                      Material Demand|Copper                             million tons/year   2.060
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.708
#                                      Material Demand|Iron Ore                           million tons/year   0.282
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2055  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.320
#                                      Material Demand|Aluminium                          million tons/year   0.118
#                                      Material Demand|Copper                             million tons/year   2.090
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.718
#                                      Material Demand|Iron Ore                           million tons/year   0.290
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2056  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.210
#                                      Material Demand|Aluminium                          million tons/year   0.120
#                                      Material Demand|Copper                             million tons/year   2.110
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.728
#                                      Material Demand|Iron Ore                           million tons/year   0.298
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2057  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.100
#                                      Material Demand|Aluminium                          million tons/year   0.121
#                                      Material Demand|Copper                             million tons/year   2.130
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.738
#                                      Material Demand|Iron Ore                           million tons/year   0.306
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2058  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       7.000
#                                      Material Demand|Aluminium                          million tons/year   0.122
#                                      Material Demand|Copper                             million tons/year   2.160
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.747
#                                      Material Demand|Iron Ore                           million tons/year   0.316
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2059  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       6.900
#                                      Material Demand|Aluminium                          million tons/year   0.124
#                                      Material Demand|Copper                             million tons/year   2.180
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.756
#                                      Material Demand|Iron Ore                           million tons/year   0.325
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
#                                                                                                              2060
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr       6.800
#                                      Material Demand|Aluminium                          million tons/year   0.125
#                                      Material Demand|Copper                             million tons/year   2.200
#                                      Material Demand|Industrial Sand and Gravel         million tons/year   0.766
#                                      Material Demand|Iron Ore                           million tons/year   0.335
# ...                                                                                                           ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %                  90.000
#                                      Recycling Rate|Iron Ore                            %                  98.000
#                                      Recycling Rate|Other Metals                        %                  49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %                  30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %                  90.000
#
# [2730 rows x 46 columns]

# %%
df_clean = pyam.IamDataFrame(df_copy)
df_clean = df_clean.rename(unit={'million tons/year':'Mt/yr'})
df_clean = df_clean.filter(year=[2000, 2010, 2020, 2030, 2040, 2050, 2060])
df_clean.to_excel(('../../../data/SOD/model_results/processed/GTEM_results_processed.xlsx'))
df_clean.timeseries()
# Out:
#                                                                                                          2020  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr  10.600
#                                      Material Demand|Aluminium                          Mt/yr           0.129
#                                      Material Demand|Copper                             Mt/yr           2.360
#                                      Material Demand|Industrial Sand and Gravel         Mt/yr           0.571
#                                      Material Demand|Iron Ore                           Mt/yr           0.268
# ...                                                                                                       ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %              70.000
#                                      Recycling Rate|Iron Ore                            %              78.000
#                                      Recycling Rate|Other Metals                        %              29.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %              10.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %              70.000
#
#                                                                                                          2030  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr  11.900
#                                      Material Demand|Aluminium                          Mt/yr           0.158
#                                      Material Demand|Copper                             Mt/yr           2.840
#                                      Material Demand|Industrial Sand and Gravel         Mt/yr           0.813
#                                      Material Demand|Iron Ore                           Mt/yr           0.356
# ...                                                                                                       ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %              76.000
#                                      Recycling Rate|Iron Ore                            %              84.000
#                                      Recycling Rate|Other Metals                        %              35.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %              14.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %              76.000
#
#                                                                                                          2040  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr  10.300
#                                      Material Demand|Aluminium                          Mt/yr           0.134
#                                      Material Demand|Copper                             Mt/yr           2.390
#                                      Material Demand|Industrial Sand and Gravel         Mt/yr           0.757
#                                      Material Demand|Iron Ore                           Mt/yr           0.283
# ...                                                                                                       ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %              83.000
#                                      Recycling Rate|Iron Ore                            %              91.000
#                                      Recycling Rate|Other Metals                        %              41.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %              21.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %              83.000
#
#                                                                                                          2050  \
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr   7.890
#                                      Material Demand|Aluminium                          Mt/yr           0.108
#                                      Material Demand|Copper                             Mt/yr           1.910
#                                      Material Demand|Industrial Sand and Gravel         Mt/yr           0.665
#                                      Material Demand|Iron Ore                           Mt/yr           0.250
# ...                                                                                                       ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %              90.000
#                                      Recycling Rate|Iron Ore                            %              98.000
#                                      Recycling Rate|Other Metals                        %              49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %              30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %              90.000
#
#                                                                                                          2060
# model              scenario   region variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 ARG    Forestry Production|Roundwood|Industrial Roundwood million m3/yr   6.800
#                                      Material Demand|Aluminium                          Mt/yr           0.125
#                                      Material Demand|Copper                             Mt/yr           2.200
#                                      Material Demand|Industrial Sand and Gravel         Mt/yr           0.766
#                                      Material Demand|Iron Ore                           Mt/yr           0.335
# ...                                                                                                       ...
#                    TECH-TP-v2 World  Recycling Rate|Industrial Sand and Gravel          %              90.000
#                                      Recycling Rate|Iron Ore                            %              98.000
#                                      Recycling Rate|Other Metals                        %              49.000
#                                      Recycling Rate|Other Non-Metallic Minerals         %              30.000
#                                      Recycling Rate|Sand Gravel and Rock for Constru... %              90.000
#
# [2730 rows x 5 columns]

# %%
def compute_UN_groups(df, variables, weight=None, method='sum'):
    df_africa = df.aggregate_region(variables,
                              region='Africa (UN-R5)',
                              subregions=[
                                'EGY',
                                'ETH',
                                'NGA',
                                'RAF',
                                'SAF',
                              ],
                              weight=weight,
                              method=method,
                              )

    df_asia = df.aggregate_region(variables,
                              region='Asia and the Pacific (UN-R5)',
                              subregions=[
                                'BGD',
                                'CHN',
                                'IND',
                                'IDN',
                                'IRN',
                                'JPN',
                                'PAK',
                                'PHL',
                                'RAP',
                                'RSA',
                                'SAU',
                                'KOR',
                                'THA',
                                'VNM',
                              ],
                              weight=weight,
                              method=method,
                              )

    df_ee = df.aggregate_region(variables,
                              region='Eastern Europe (UN-R5)',
                              subregions=[
                                'ECA',
                                'RUS',
                              ],
                              weight=weight,
                              method=method,
                              )

    df_latin = df.aggregate_region(variables,
                              region='Latin America and Caribbean (UN-R5)',
                              subregions=[
                                'ARG',
                                'BRA',
                                'MEX',
                                'LAC',
                              ],
                              weight=weight,
                              method=method,
                              )

    df_we = df.aggregate_region(variables,
                              region='Western Europe and Other States (UN-R5)',
                              subregions=[
                                'AUS',
                                'CAN',
                                'FRA',
                                'DEU',
                                'ITA',
                                'ROE',
                                'TUR',
                                'GBR',
                                'USA',
                              ],
                              weight=weight,
                              method=method,
                              )

    df_world = df.filter(region='World', variable=variables)
    
    df_un_groups = pyam.concat([df_africa, df_asia, df_ee, df_latin, df_we, df_world])
    return df_un_groups

# %%
mean_vars = [
    'Recycling Rate|Aluminium',
    'Recycling Rate|Copper',
    'Recycling Rate|Industrial Roundwood',
    'Recycling Rate|Industrial Sand and Gravel',
    'Recycling Rate|Iron Ore',
    'Recycling Rate|Other Metals',
    'Recycling Rate|Other Non-Metallic Minerals',
    'Recycling Rate|Sand Gravel and Rock for Construction'
]

abs_variables = [value for value in df_clean.variable if value not in mean_vars]

df_clean_un_abs = compute_UN_groups(df_clean, abs_variables)
df_clean_un_mean = compute_UN_groups(df_clean, mean_vars, method='mean')
df_clean_un = pyam.concat([df_clean_un_abs, df_clean_un_mean])
df_clean_un.timeseries()
# Out:
# c:\PBLprogs\miniforge3\lib\site-packages\pyam\aggregation.py:209: FutureWarning: The provided callable <function mean at 0x0000013E4AA1B520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# c:\PBLprogs\miniforge3\lib\site-packages\pyam\aggregation.py:209: FutureWarning: The provided callable <function mean at 0x0000013E4AA1B520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# c:\PBLprogs\miniforge3\lib\site-packages\pyam\aggregation.py:209: FutureWarning: The provided callable <function mean at 0x0000013E4AA1B520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# c:\PBLprogs\miniforge3\lib\site-packages\pyam\aggregation.py:209: FutureWarning: The provided callable <function mean at 0x0000013E4AA1B520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
# c:\PBLprogs\miniforge3\lib\site-packages\pyam\aggregation.py:209: FutureWarning: The provided callable <function mean at 0x0000013E4AA1B520> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   return df.groupby(cols).agg(_get_method_func(method))
#                                                                                                                      2020  \
# model              scenario   region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   70.710000
#                                              Material Demand|Aluminium                          Mt/yr           41.957214
#                                              Material Demand|Copper                             Mt/yr          124.935585
#                                              Material Demand|Industrial Sand and Gravel         Mt/yr            4.669100
#                                              Material Demand|Iron Ore                           Mt/yr            1.860317
# ...                                                                                                                   ...
#                    TECH-TP-v2 World          Recycling Rate|Industrial Sand and Gravel          %               70.000000
#                                              Recycling Rate|Iron Ore                            %               78.000000
#                                              Recycling Rate|Other Metals                        %               29.000000
#                                              Recycling Rate|Other Non-Metallic Minerals         %               10.000000
#                                              Recycling Rate|Sand Gravel and Rock for Constru... %               70.000000
#
#                                                                                                                    2030  \
# model              scenario   region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   72.2320
#                                              Material Demand|Aluminium                          Mt/yr           87.0401
#                                              Material Demand|Copper                             Mt/yr          258.2144
#                                              Material Demand|Industrial Sand and Gravel         Mt/yr            5.9729
#                                              Material Demand|Iron Ore                           Mt/yr            2.9418
# ...                                                                                                                 ...
#                    TECH-TP-v2 World          Recycling Rate|Industrial Sand and Gravel          %               76.0000
#                                              Recycling Rate|Iron Ore                            %               84.0000
#                                              Recycling Rate|Other Metals                        %               35.0000
#                                              Recycling Rate|Other Non-Metallic Minerals         %               14.0000
#                                              Recycling Rate|Sand Gravel and Rock for Constru... %               76.0000
#
#                                                                                                                    2040  \
# model              scenario   region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   56.2010
#                                              Material Demand|Aluminium                          Mt/yr          139.8967
#                                              Material Demand|Copper                             Mt/yr          414.0301
#                                              Material Demand|Industrial Sand and Gravel         Mt/yr            5.7600
#                                              Material Demand|Iron Ore                           Mt/yr            3.3338
# ...                                                                                                                 ...
#                    TECH-TP-v2 World          Recycling Rate|Industrial Sand and Gravel          %               83.0000
#                                              Recycling Rate|Iron Ore                            %               91.0000
#                                              Recycling Rate|Other Metals                        %               41.0000
#                                              Recycling Rate|Other Non-Metallic Minerals         %               21.0000
#                                              Recycling Rate|Sand Gravel and Rock for Constru... %               83.0000
#
#                                                                                                                    2050  \
# model              scenario   region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   40.7120
#                                              Material Demand|Aluminium                          Mt/yr          115.9263
#                                              Material Demand|Copper                             Mt/yr          344.1538
#                                              Material Demand|Industrial Sand and Gravel         Mt/yr            5.4610
#                                              Material Demand|Iron Ore                           Mt/yr            2.8440
# ...                                                                                                                 ...
#                    TECH-TP-v2 World          Recycling Rate|Industrial Sand and Gravel          %               90.0000
#                                              Recycling Rate|Iron Ore                            %               98.0000
#                                              Recycling Rate|Other Metals                        %               49.0000
#                                              Recycling Rate|Other Non-Metallic Minerals         %               30.0000
#                                              Recycling Rate|Sand Gravel and Rock for Constru... %               90.0000
#
#                                                                                                                    2060
# model              scenario   region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP-v2 Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   41.3800
#                                              Material Demand|Aluminium                          Mt/yr           85.0867
#                                              Material Demand|Copper                             Mt/yr          255.0207
#                                              Material Demand|Industrial Sand and Gravel         Mt/yr            7.1368
#                                              Material Demand|Iron Ore                           Mt/yr            4.4683
# ...                                                                                                                 ...
#                    TECH-TP-v2 World          Recycling Rate|Industrial Sand and Gravel          %               90.0000
#                                              Recycling Rate|Iron Ore                            %               98.0000
#                                              Recycling Rate|Other Metals                        %               49.0000
#                                              Recycling Rate|Other Non-Metallic Minerals         %               30.0000
#                                              Recycling Rate|Sand Gravel and Rock for Constru... %               90.0000
#
# [468 rows x 5 columns]

# %%
def plot_data_3_x_3_figures(df, title_dict=None, path_dict=None, variables=None,):

    # Define the color palette for scenarios
    scenario_colors = {
        "REF": "black",
        "LIFE-TP": "orange",
        "TECH-TP": "magenta",
        "REF-v2": "black",
        "LIFE-TP-v2": "orange",
        "TECH-TP-v2": "magenta",
    }

    df_plotting = df.filter(year=[2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050]).timeseries().reset_index()
    df_compare_data = pd.melt(df_plotting, id_vars=['model',
                                'scenario',
                                'region',
                                'variable',
                                'unit'
                                    ], var_name='year', value_name='value')
    df_compare_data['year'] = df_compare_data['year'].astype(int)

    if variables is None:
        variables = df.variable

    for variable in variables:
        df_var = df_compare_data[df_compare_data["variable"] == variable]
        # Get unique regions for creating subplots
        unique_regions = df_var['region'].unique()

        # Create subplots based on the number of unique regions
        fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))

        # Initialize lists to store handles and labels for the legend
        legend_handles = []
        legend_labels = []

        # Iterate through each region and plot in respective subplot
        for idx, region in enumerate(unique_regions):
            row_idx = idx // 3
            col_idx = idx % 3
            
            ax = axes[row_idx, col_idx]  # Select the current subplot
            
            region_data = df_var[df_var['region'] == region]  # Filter data for the current region
            
            # Plot lineplots for each region
            lineplot = sns.lineplot(data=region_data, 
                                    x="year", 
                                    y="value", 
                                    hue="scenario", 
                                    # style='model', 
                                    palette=scenario_colors, 
                                    linewidth=2.5, 
                                    ax=ax)
            
            # Customize ticks and labels for the current subplot
            ax.set_ylabel(region_data["unit"].iloc[0], fontsize=14)  # Set the y-axis label to the unit
            # Set y-axis lower limit to 0
            ax.set_ylim(min(0,ax.get_ylim()[0]), ax.get_ylim()[1])
            ax.set_xlabel('', fontsize=1)
            ax.set_title(f"{region}", fontsize=14)  # Set the title to the region
            ax.set_xticks([2010, 2020, 2030, 2040, 2050])
            ax.set_xticklabels([2010, 2020, 2030, 2040, 2050], 
                            rotation=45, fontsize=14)
            
            # Increase fontsize of y-axis tick labels
            ax.tick_params(axis='y', labelsize=14)

            # Add the lineplot to the legend manually
            legend_handles.append(lineplot)
            legend_labels.append(region)
            # Disable the legend for individual subplots
            ax.legend().set_visible(False)
            ax.grid(True)

            # Add a gray background for the 'World' region subplot
            if region == 'World':
                ax.set_facecolor(color='#ededed')

        # Show legend and grid for the current subplot
        if title_dict:
            fig.suptitle(f"{title_dict[variable]}", fontsize=16)
        else:
            fig.suptitle(variable, fontsize=16)

        handles, labels = ax.get_legend_handles_labels()
        fig.legend(handles, labels, title="Legend", bbox_to_anchor=(1.12, 0.55))
        plt.tight_layout()  # Adjust subplots to prevent overlap
        
        if path_dict:
            root_variable = variable.split("|")[0].replace(" ", "_")
            variable_name = variable.replace("|", "_").replace(" ", "_").replace("/", "")
            # plt.savefig(f"../../../plots/SOD/chpt_20/Regional/{path_dict[variable]}/{variable_name}.png", bbox_inches='tight')
            # plt.close()

# %%
def plot_data_individual_figures(df, title_dict=None, path_dict=None, variables=None,):
    # Define the color palette for scenarios
    scenario_colors = {
        "REF": "black",
        "LIFE-TP": "orange",
        "TECH-TP": "magenta",
        "REF-v2": "black",
        "LIFE-TP-v2": "orange",
        "TECH-TP-v2": "magenta",
    }

    regions_dict = {
        'Africa (UN-R5)': 'Africa',
        'Asia and the Pacific (UN-R5)': 'AatP',
        'Eastern Europe (UN-R5)': 'EE',
        'Latin America and Caribbean (UN-R5)': 'LaaC',
        'Western Europe and Other States (UN-R5)': 'WeoS'
                }
    
    if variables is None:
            variables = df.variable

    for region in list(regions_dict.keys()):
        df_plotting = df.filter(year=[2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050], region=region).timeseries().reset_index()

        
        df_selected = df_plotting[df_plotting['variable'].isin(variables)]

        df_compare_data = pd.melt(df_selected, id_vars=['model',
                                    'scenario',
                                    'region',
                                    'variable',
                                    'unit'
                                        ], var_name='year', value_name='value')
        df_compare_data['year'] = df_compare_data['year'].astype(int)

        

        for variable in variables: # ,variables
            # Use Seaborn to create the plot with markers and lines
            data = df_compare_data[df_compare_data["variable"] == variable]

            fig, ax = plt.subplots(figsize=(10, 6))  # Set figure size
            sns.lineplot(
                data=data,
                x="year",
                y="value",
                hue="scenario",
                # style="model",
                dashes=True,
                palette=scenario_colors,
            )

            # Set labels and title
            plt.xlabel("Year")
            plt.ylabel(data["unit"].iloc[0])  # Set the y-axis label to the unit
            # Set y-axis lower limit to 0
            ax.set_ylim(min(0,ax.get_ylim()[0]), ax.get_ylim()[1])
            # Mid point of left and right x-positions
            mid = (fig.subplotpars.right + fig.subplotpars.left)/2
            if title_dict:
                plt.suptitle(title_dict[variable], x=0.4)  # Set the title to the variable
                plt.title(region)
            else:
                fig.suptitle(variable, fontsize=16)
            # Show legend and grid
            plt.legend(title="Legend", bbox_to_anchor=(1.3, 1))
            plt.grid(True)
            # Adjust layout to ensure legend fits within the saved image
            plt.tight_layout()
            # root_variable = variable.split("|")[0].replace(" ", "_")
            if path_dict:
                variable_name = variable.replace(" > 25 μg/m3", "").replace("|", "_").replace(" ", "_").replace("/", "")
                plt.savefig(
                    f"../../../plots/SOD/chpt_20/Regional/{regions_dict[region]}/{path_dict[variable]}/{variable_name}.png"
                )
                plt.close()

# %%
df_figures = df_clean_un.copy()
df_figures = df_figures.filter(
    scenario=['REF-v2', 'TECH-TP-v2', 'LIFE-TP-v2'],
    region=[
        'Africa (UN-R5)',
        'Asia and the Pacific (UN-R5)',
        'Eastern Europe (UN-R5)',
        'Latin America and Caribbean (UN-R5)',
        'Western Europe and Other States (UN-R5)',
        'World',],
    model='GTEM-Resource_2023'
                    )
df_figures = df_figures.rename(scenario={
    'REF-v2':'REF', 
    'TECH-TP-v2':'TECH-TP', 
    'LIFE-TP-v2':'LIFE-TP'})
df_figures.timeseries()
# Out:
#                                                                                                                    2020  \
# model              scenario region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP  Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   70.710000
#                                            Material Demand|Aluminium                          Mt/yr           41.957214
#                                            Material Demand|Copper                             Mt/yr          124.935585
#                                            Material Demand|Industrial Sand and Gravel         Mt/yr            4.669100
#                                            Material Demand|Iron Ore                           Mt/yr            1.860317
# ...                                                                                                                 ...
#                    TECH-TP  World          Recycling Rate|Industrial Sand and Gravel          %               70.000000
#                                            Recycling Rate|Iron Ore                            %               78.000000
#                                            Recycling Rate|Other Metals                        %               29.000000
#                                            Recycling Rate|Other Non-Metallic Minerals         %               10.000000
#                                            Recycling Rate|Sand Gravel and Rock for Constru... %               70.000000
#
#                                                                                                                  2030  \
# model              scenario region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP  Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   72.2320
#                                            Material Demand|Aluminium                          Mt/yr           87.0401
#                                            Material Demand|Copper                             Mt/yr          258.2144
#                                            Material Demand|Industrial Sand and Gravel         Mt/yr            5.9729
#                                            Material Demand|Iron Ore                           Mt/yr            2.9418
# ...                                                                                                               ...
#                    TECH-TP  World          Recycling Rate|Industrial Sand and Gravel          %               76.0000
#                                            Recycling Rate|Iron Ore                            %               84.0000
#                                            Recycling Rate|Other Metals                        %               35.0000
#                                            Recycling Rate|Other Non-Metallic Minerals         %               14.0000
#                                            Recycling Rate|Sand Gravel and Rock for Constru... %               76.0000
#
#                                                                                                                  2040  \
# model              scenario region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP  Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   56.2010
#                                            Material Demand|Aluminium                          Mt/yr          139.8967
#                                            Material Demand|Copper                             Mt/yr          414.0301
#                                            Material Demand|Industrial Sand and Gravel         Mt/yr            5.7600
#                                            Material Demand|Iron Ore                           Mt/yr            3.3338
# ...                                                                                                               ...
#                    TECH-TP  World          Recycling Rate|Industrial Sand and Gravel          %               83.0000
#                                            Recycling Rate|Iron Ore                            %               91.0000
#                                            Recycling Rate|Other Metals                        %               41.0000
#                                            Recycling Rate|Other Non-Metallic Minerals         %               21.0000
#                                            Recycling Rate|Sand Gravel and Rock for Constru... %               83.0000
#
#                                                                                                                  2050  \
# model              scenario region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP  Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   40.7120
#                                            Material Demand|Aluminium                          Mt/yr          115.9263
#                                            Material Demand|Copper                             Mt/yr          344.1538
#                                            Material Demand|Industrial Sand and Gravel         Mt/yr            5.4610
#                                            Material Demand|Iron Ore                           Mt/yr            2.8440
# ...                                                                                                               ...
#                    TECH-TP  World          Recycling Rate|Industrial Sand and Gravel          %               90.0000
#                                            Recycling Rate|Iron Ore                            %               98.0000
#                                            Recycling Rate|Other Metals                        %               49.0000
#                                            Recycling Rate|Other Non-Metallic Minerals         %               30.0000
#                                            Recycling Rate|Sand Gravel and Rock for Constru... %               90.0000
#
#                                                                                                                  2060
# model              scenario region         variable                                           unit
# GTEM-Resource_2023 LIFE-TP  Africa (UN-R5) Forestry Production|Roundwood|Industrial Roundwood million m3/yr   41.3800
#                                            Material Demand|Aluminium                          Mt/yr           85.0867
#                                            Material Demand|Copper                             Mt/yr          255.0207
#                                            Material Demand|Industrial Sand and Gravel         Mt/yr            7.1368
#                                            Material Demand|Iron Ore                           Mt/yr            4.4683
# ...                                                                                                               ...
#                    TECH-TP  World          Recycling Rate|Industrial Sand and Gravel          %               90.0000
#                                            Recycling Rate|Iron Ore                            %               98.0000
#                                            Recycling Rate|Other Metals                        %               49.0000
#                                            Recycling Rate|Other Non-Metallic Minerals         %               30.0000
#                                            Recycling Rate|Sand Gravel and Rock for Constru... %               90.0000
#
# [468 rows x 5 columns]

# %%
df_figures.subtract('Material Demand|Total', ['Material Demand|Aluminium',
 'Material Demand|Copper',
 'Material Demand|Industrial Sand and Gravel',
 'Material Demand|Iron Ore',
 'Material Demand|Other Metals and Concentrates',
 'Material Demand|Other Non-Metallic Minerals',
 'Material Demand|Sand Gravel and Rock for Construction',
 'Material Demand|Wild Catch',], 'Material Demand|Other Materials', append=True)

# %%
path_dict = {
    'Forestry Production|Roundwood|Industrial Roundwood':'Materials_and_Circularity',
    'Material Demand|Aluminium':'Materials_and_Circularity',
    'Material Demand|Copper':'Materials_and_Circularity',
    'Material Demand|Industrial Sand and Gravel':'Materials_and_Circularity',
    'Material Demand|Iron Ore':'Materials_and_Circularity',
    'Material Demand|Other Metals and Concentrates':'Materials_and_Circularity',
    'Material Demand|Other Non-Metallic Minerals':'Materials_and_Circularity',
    'Material Demand|Sand Gravel and Rock for Construction':'Materials_and_Circularity',
    'Material Demand|Total':'Materials_and_Circularity',
    'Material Demand|Wild Catch':'Materials_and_Circularity',
    'Material Demand|Other Materials':'Materials_and_Circularity',
    'Material Extraction|Aluminium':'Materials_and_Circularity',
    'Material Extraction|Copper':'Materials_and_Circularity',
    'Material Extraction|Industrial Sand and Gravel':'Materials_and_Circularity',
    'Material Extraction|Iron Ore':'Materials_and_Circularity',
    'Material Extraction|Other Metals and Concentrates':'Materials_and_Circularity',
    'Material Extraction|Other Non-Metallic Minerals':'Materials_and_Circularity',
    'Material Extraction|Sand Gravel and Rock for Construction':'Materials_and_Circularity',
    'Material Extraction|Wild Catch':'Materials_and_Circularity',
    'Recycling Rate|Aluminium':'Materials_and_Circularity',
    'Recycling Rate|Copper':'Materials_and_Circularity',
    'Recycling Rate|Industrial Roundwood':'Materials_and_Circularity',
    'Recycling Rate|Industrial Sand and Gravel':'Materials_and_Circularity',
    'Recycling Rate|Iron Ore':'Materials_and_Circularity',
    'Recycling Rate|Other Metals':'Materials_and_Circularity',
    'Recycling Rate|Other Non-Metallic Minerals':'Materials_and_Circularity',
    'Recycling Rate|Sand Gravel and Rock for Construction':'Materials_and_Circularity'}

title_dict = {}

# plot_data_individual_figures(df_figures, path_dict=path_dict, )
df_figures.to_excel('../../../data/SOD/model_results/to_share/GTEM_to_share.xlsx')
